# %% [markdown]
# **This notebook provides examples of how to verify the performance of GCNNs on the validation set (function: reverify_sigopt_models), select the top-performing models accordingly (function: keep_the_best_few_models), compute the prediction on the test and holdout sets (function: get_all_model_predictions), and extract the latent embeddings of CGCNN and e3nn after all message passing and graph convolution layers (function: get_all_embeddings).**
#
# Parameters:
# - struct_type: the structure representation to use (options: unrelaxed, relaxed, M3Gnet_relaxed)
# - model_type: the model architechture to use (options: CGCNN, e3nn, Painn)
# - gpu_num: the GPU to use
# - training_fraction: if not trained on the entire training set, the fraction of the training set to use
# - num_best_models: the number of top-performing models to use

# %%
from inference.select_best_models import reverify_wandb_models, keep_the_best_few_models
from inference.test_model_prediction import get_all_model_predictions
from inference.embedding_extraction import get_all_embeddings

# %% [markdown]
# # CGCNN

# %%
reverify_wandb_models(
    model_params={
        "struct_type": "unrelaxed",
        "model_type": "CGCNN",
        "training_fraction":1.0,
    },
    gpu_num=0
)
# Out:
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8605.95it/s]
# 100%|██████████| 1277/1277 [00:00<00:00, 8486.59it/s]
# Reverifying wandb model #0 (observ_09b2uh9s)
# 100%|██████████| 6276/6276 [01:27<00:00, 71.89it/s]
# Reverifying wandb model #1 (observ_2bwzbm4a)
# 100%|██████████| 6276/6276 [00:00<00:00, 28012.25it/s]
# Reverifying wandb model #2 (observ_2jcubzj4)
# 100%|██████████| 6276/6276 [00:00<00:00, 29388.66it/s]
# Reverifying wandb model #3 (observ_2s73ddgv)
# 100%|██████████| 6276/6276 [00:00<00:00, 28516.61it/s]
# Reverifying wandb model #4 (observ_3oiczxq2)
# 100%|██████████| 6276/6276 [00:00<00:00, 29691.78it/s]
# Reverifying wandb model #5 (observ_49tl4l12)
# 100%|██████████| 6276/6276 [00:00<00:00, 29821.48it/s]
# Reverifying wandb model #6 (observ_4p8z3i0m)
# 100%|██████████| 6276/6276 [00:00<00:00, 29761.03it/s]
# Reverifying wandb model #7 (observ_54cqu9ml)
# 100%|██████████| 6276/6276 [00:00<00:00, 29479.43it/s]
# Reverifying wandb model #8 (observ_5d1b1xg1)
# 100%|██████████| 6276/6276 [00:00<00:00, 29624.24it/s]
# Reverifying wandb model #9 (observ_5p8h9jh5)
# 100%|██████████| 6276/6276 [00:00<00:00, 29662.33it/s]
# Reverifying wandb model #10 (observ_6plr3lcq)
# 100%|██████████| 6276/6276 [00:00<00:00, 29276.42it/s]
# Reverifying wandb model #11 (observ_80rmxv0j)
# 100%|██████████| 6276/6276 [00:00<00:00, 29411.02it/s]
# Reverifying wandb model #12 (observ_8ba9sw4k)
# 100%|██████████| 6276/6276 [00:00<00:00, 29457.56it/s]
# Reverifying wandb model #13 (observ_8bhrm4hf)
# 100%|██████████| 6276/6276 [00:00<00:00, 29433.71it/s]
# Reverifying wandb model #14 (observ_9u97mm6a)
# 100%|██████████| 6276/6276 [00:00<00:00, 29421.74it/s]
# Reverifying wandb model #15 (observ_a45136sx)
# 100%|██████████| 6276/6276 [00:00<00:00, 29636.25it/s]
# Reverifying wandb model #16 (observ_adi6wl92)
# 100%|██████████| 6276/6276 [00:00<00:00, 29522.54it/s]
# Reverifying wandb model #17 (observ_augud3u4)
# 100%|██████████| 6276/6276 [00:00<00:00, 29413.45it/s]
# Reverifying wandb model #18 (observ_bcwl2zpk)
# 100%|██████████| 6276/6276 [00:00<00:00, 29637.65it/s]
# Reverifying wandb model #19 (observ_cdccpbp8)
# 100%|██████████| 6276/6276 [00:00<00:00, 29391.42it/s]
# Reverifying wandb model #20 (observ_ckylh4ug)
# 100%|██████████| 6276/6276 [00:00<00:00, 29807.97it/s]
# Reverifying wandb model #21 (observ_cwcwhkko)
# 100%|██████████| 6276/6276 [00:00<00:00, 28697.98it/s]
# Reverifying wandb model #22 (observ_d5v1z4ej)
# 100%|██████████| 6276/6276 [00:00<00:00, 29584.49it/s]
# Reverifying wandb model #23 (observ_du222f4z)
# 100%|██████████| 6276/6276 [00:00<00:00, 29658.46it/s]
# Reverifying wandb model #24 (observ_dvpqu60a)
# 100%|██████████| 6276/6276 [00:00<00:00, 29495.91it/s]
# Reverifying wandb model #25 (observ_enpygz6a)
# 100%|██████████| 6276/6276 [00:00<00:00, 29322.04it/s]
# Reverifying wandb model #26 (observ_f9v9jrkm)
# 100%|██████████| 6276/6276 [00:00<00:00, 29694.39it/s]
# Reverifying wandb model #27 (observ_hi3k26oe)
# 100%|██████████| 6276/6276 [00:00<00:00, 29463.53it/s]
# Reverifying wandb model #28 (observ_hyr6xdjg)
# 100%|██████████| 6276/6276 [00:00<00:00, 28107.61it/s]
# Reverifying wandb model #29 (observ_imb9ao61)
# 100%|██████████| 6276/6276 [00:00<00:00, 6368.81it/s]
# Reverifying wandb model #30 (observ_jisd1e8m)
# 100%|██████████| 6276/6276 [00:00<00:00, 29735.21it/s]
# Reverifying wandb model #31 (observ_jyjgs8ey)
# 100%|██████████| 6276/6276 [00:00<00:00, 29546.77it/s]
# Reverifying wandb model #32 (observ_kfkaui6j)
# 100%|██████████| 6276/6276 [00:00<00:00, 29387.05it/s]
# Reverifying wandb model #33 (observ_km814edf)
# 100%|██████████| 6276/6276 [00:00<00:00, 29381.97it/s]
# Reverifying wandb model #34 (observ_l4gxd8lw)
# 100%|██████████| 6276/6276 [00:00<00:00, 27695.87it/s]
# Reverifying wandb model #35 (observ_lm0yimqa)
# 100%|██████████| 6276/6276 [00:00<00:00, 29639.82it/s]
# Reverifying wandb model #36 (observ_mhickp7v)
# 100%|██████████| 6276/6276 [00:00<00:00, 29755.18it/s]
# Reverifying wandb model #37 (observ_n2phdmek)
# 100%|██████████| 6276/6276 [00:00<00:00, 29677.38it/s]
# Reverifying wandb model #38 (observ_npavtj6h)
# 100%|██████████| 6276/6276 [00:00<00:00, 29506.10it/s]
# Reverifying wandb model #39 (observ_nsu2734z)
# 100%|██████████| 6276/6276 [00:00<00:00, 28249.50it/s]
# Reverifying wandb model #40 (observ_qf9pdl27)
# 100%|██████████| 6276/6276 [00:00<00:00, 29341.82it/s]
# Reverifying wandb model #41 (observ_r7yaxfue)
# 100%|██████████| 6276/6276 [00:00<00:00, 28644.02it/s]
# Reverifying wandb model #42 (observ_reblty69)
# 100%|██████████| 6276/6276 [00:00<00:00, 29670.22it/s]
# Reverifying wandb model #43 (observ_s1dx510i)
# 100%|██████████| 6276/6276 [00:00<00:00, 29651.01it/s]
# Reverifying wandb model #44 (observ_vfu3r9k7)
# 100%|██████████| 6276/6276 [00:00<00:00, 29556.89it/s]
# Reverifying wandb model #45 (observ_w3yiycgl)
# 100%|██████████| 6276/6276 [00:00<00:00, 29596.80it/s]
# Reverifying wandb model #46 (observ_x8g0t2zu)
# 100%|██████████| 6276/6276 [00:00<00:00, 28785.44it/s]
# Reverifying wandb model #47 (observ_x9qeeoja)
# 100%|██████████| 6276/6276 [00:00<00:00, 29661.36it/s]
# Reverifying wandb model #48 (observ_xbnsp9u1)
# 100%|██████████| 6276/6276 [00:00<00:00, 28617.05it/s]
# Reverifying wandb model #49 (observ_zg25g5s9)
# 100%|██████████| 6276/6276 [00:00<00:00, 29693.22it/s]

# %%
keep_the_best_few_models(
    model_params={
        "struct_type": "unrelaxed",
        "model_type": "CGCNN",
        "training_fraction":1.0,
    },
    num_best_models=3
)
# Out:
# Copied model observ_du222f4z to best_0
# Copied model observ_augud3u4 to best_1
# Copied model observ_jisd1e8m to best_2
# Kept the best 3 models in ./best_models/CGCNN/dft_e_hull_htvs_data_unrelaxed_CGCNN

# %%
get_all_model_predictions(
    model_params={
        "struct_type": "unrelaxed",
        "model_type": "CGCNN",
        "training_fraction":1.0,
    },
    gpu_num=0,
    num_best_models=3
)
# Out:
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8582.70it/s]
# 100%|██████████| 1261/1261 [00:00<00:00, 8386.20it/s]
# 100%|██████████| 6276/6276 [01:28<00:00, 70.77it/s]
# Timing...
# 19.374361753463745
# 19.77317476272583
# 100%|██████████| 6276/6276 [00:00<00:00, 28517.56it/s]
# Timing...
# 0.6810338497161865
# 1.0798468589782715
# 100%|██████████| 6276/6276 [00:00<00:00, 28278.88it/s]
# Timing...
# 0.6692249774932861
# 1.068037986755371
# Completed model prediction for test_set
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8342.05it/s]
# 100%|██████████| 600/600 [00:00<00:00, 8581.52it/s]
# 100%|██████████| 6276/6276 [01:29<00:00, 70.27it/s]
# Timing...
# 10.09644889831543
# 10.2840576171875
# 100%|██████████| 6276/6276 [00:00<00:00, 26744.11it/s]
# Timing...
# 0.3335995674133301
# 0.5212082862854004
# 100%|██████████| 6276/6276 [00:00<00:00, 28275.02it/s]
# Timing...
# 0.32080578804016113
# 0.5084145069122314
# Completed model prediction for holdout_set_B_sites
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8295.12it/s]
# 100%|██████████| 863/863 [00:00<00:00, 8340.32it/s]
# 100%|██████████| 6276/6276 [01:28<00:00, 71.31it/s]
# Timing...
# 13.80959701538086
# 14.086063623428345
# 100%|██████████| 6276/6276 [00:00<00:00, 28615.84it/s]
# Timing...
# 0.4729421138763428
# 0.7494087219238281
# 100%|██████████| 6276/6276 [00:00<00:00, 28612.60it/s]
# Timing...
# 0.4615757465362549
# 0.7380423545837402
# Completed model prediction for holdout_set_series

# %%
get_all_embeddings(
    model_params={
        "struct_type": "unrelaxed",
        "model_type": "CGCNN",
        "training_fraction":1.0,
    },
    gpu_num=0,
    num_best_models=3
)
# Out:
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8348.79it/s]
# 100%|██████████| 1261/1261 [00:00<00:00, 8336.74it/s]
# 100%|██████████| 6276/6276 [01:28<00:00, 71.25it/s]
# 100%|██████████| 6276/6276 [00:00<00:00, 30239.53it/s]
# 100%|██████████| 6276/6276 [00:00<00:00, 29867.30it/s]
# Completed embedding extraction for test_set
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8359.19it/s]
# 100%|██████████| 600/600 [00:00<00:00, 8386.85it/s]
# 100%|██████████| 6276/6276 [01:29<00:00, 70.25it/s]
# 100%|██████████| 6276/6276 [00:00<00:00, 29880.65it/s]
# 100%|██████████| 6276/6276 [00:00<00:00, 29005.38it/s]
# Completed embedding extraction for holdout_set_B_sites
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8363.62it/s]
# 100%|██████████| 863/863 [00:00<00:00, 8363.10it/s]
# 100%|██████████| 6276/6276 [01:31<00:00, 68.90it/s]
# 100%|██████████| 6276/6276 [00:00<00:00, 30298.95it/s]
# 100%|██████████| 6276/6276 [00:00<00:00, 29643.19it/s]
# Completed embedding extraction for holdout_set_series

# %% [markdown]
# # e3nn

# %%
reverify_wandb_models(
    model_params={
        "struct_type": "relaxed",
        "model_type": "e3nn",
        "training_fraction":0.5,
    },
    gpu_num=0
)

# %%
keep_the_best_few_models(
    model_params={
        "struct_type": "relaxed",
        "model_type": "e3nn",
        "training_fraction":0.5,
    },
    num_best_models=3
)

# %%
get_all_model_predictions(
    model_params={
        "struct_type": "relaxed",
        "model_type": "e3nn",
        "training_fraction":0.5,
    },
    gpu_num=0,
    num_best_models=3
)

# %%
get_all_embeddings(
    model_params={
        "struct_type": "relaxed",
        "model_type": "e3nn",
        "training_fraction":1,
    },
    gpu_num=0,
    num_best_models=3
)
# Out:
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 7782.24it/s]
#  98%|█████████▊| 6170/6276 [09:53<00:10, 10.40it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_all_embeddings(
#       2     model_params={
#       3         "struct_type": "relaxed",
#       4         "model_type": "e3nn",
#       5         "training_fraction":1,
#       6     },
#       7     gpu_num=0,
#       8     num_best_models=3
#       9 )
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/inference/embedding_extraction.py:27, in get_all_embeddings(model_params, gpu_num, num_best_models, target_prop, depth)
#      24 model_params["long_range"] = False
#      26 for test_set_type in ["test_set", "holdout_set_B_sites", "holdout_set_series"]:
# ---> 27     get_model_embedding(test_set_type, model_params, gpu_num, num_best_models, target_prop, depth)
#      28     print("Completed embedding extraction for " + test_set_type)
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/inference/embedding_extraction.py:88, in get_model_embedding(test_set_type, model_params, gpu_num, num_best_models, target_prop, depth)
#      85 train_data = processed_data[0]
#      86 test_data = processed_data[1]
# ---> 88 train_loader = get_dataloader(train_data,target_prop,model_type,1,interpolation)
#      89 test_loader = get_dataloader(test_data,target_prop,model_type,1,interpolation)
#      91 # Original SigOpt name building (commented out)
#      92 # sigopt_name = build_sigopt_name(model_params["data"], target_prop, model_params["struct_type"], model_params["interpolation"], model_params["model_type"],contrastive_weight=model_params["contrastive_weight"],training_fraction=model_params["training_fraction"])
#      93 # exp_id = get_experiment_id(model_params, target_prop)
#      94
#      95 # Wandb name building (active)
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/processing/dataloader/dataloader.py:73, in get_dataloader(data, prop, model_type, batch_size, interpolation, per_site, long_range, device)
#      71     data_loader = get_painn_dataloader(data,prop,batch_size)
#      72 elif model_type == "e3nn":
# ---> 73     data_loader = get_e3nn_dataloader(data,prop,batch_size,per_site=per_site)
#      74 elif model_type == "e3nn_contrastive":
#      75     data_loader = get_e3nn_contrastive_dataloader(data,prop,batch_size)
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/processing/dataloader/dataloader.py:102, in get_e3nn_dataloader(data, prop, batch_size, per_site)
#     101 def get_e3nn_dataloader(data,prop,batch_size,per_site):
# --> 102     data['datapoint'] = data.progress_apply(lambda x: build_e3nn_data(x, prop, r_max=5.0,per_site=per_site), axis=1)
#     103     data_loader = tg.loader.DataLoader(data['datapoint'].values, batch_size=batch_size, shuffle=True)
#     105     return data_loader
#
# File /data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/tqdm/std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File /data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File /data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File /data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File /data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# File /data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/tqdm/std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/processing/dataloader/dataloader.py:102, in get_e3nn_dataloader.<locals>.<lambda>(x)
#     101 def get_e3nn_dataloader(data,prop,batch_size,per_site):
# --> 102     data['datapoint'] = data.progress_apply(lambda x: build_e3nn_data(x, prop, r_max=5.0,per_site=per_site), axis=1)
#     103     data_loader = tg.loader.DataLoader(data['datapoint'].values, batch_size=batch_size, shuffle=True)
#     105     return data_loader
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/processing/dataloader/build_data.py:83, in build_e3nn_data(entry, prop, r_max, per_site)
#      76 else:
#      77     target_data = torch.tensor([entry[prop]]).unsqueeze(0)
#      79 data = tg.data.Data(
#      80     pos=positions, lattice=lattice, symbol=symbols,
#      81     comp = curr_comp,
#      82     x=atom_inits_cgcnn[[type_encoding[specie] for specie in symbols]], # CGCNN-type embedding (node feature)
# ---> 83     z=atom_inits_cgcnn[[type_encoding[specie] for specie in symbols]], # CGCNN-type embedding (node attribute)
#      84     edge_index=torch.stack([torch.LongTensor(edge_src), torch.LongTensor(edge_dst)], dim=0),
#      85     edge_shift=torch.tensor(edge_shift, dtype=default_dtype),
#      86     edge_vec=edge_vec,
#      87     edge_len=edge_len,
#      88     target=target_data,
#      89     idx=torch.tensor([entry['idx']]).unsqueeze(0)
#      90 )
#      92 return data
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/processing/dataloader/build_data.py:83, in <listcomp>(.0)
#      76 else:
#      77     target_data = torch.tensor([entry[prop]]).unsqueeze(0)
#      79 data = tg.data.Data(
#      80     pos=positions, lattice=lattice, symbol=symbols,
#      81     comp = curr_comp,
#      82     x=atom_inits_cgcnn[[type_encoding[specie] for specie in symbols]], # CGCNN-type embedding (node feature)
# ---> 83     z=atom_inits_cgcnn[[type_encoding[specie] for specie in symbols]], # CGCNN-type embedding (node attribute)
#      84     edge_index=torch.stack([torch.LongTensor(edge_src), torch.LongTensor(edge_dst)], dim=0),
#      85     edge_shift=torch.tensor(edge_shift, dtype=default_dtype),
#      86     edge_vec=edge_vec,
#      87     edge_len=edge_len,
#      88     target=target_data,
#      89     idx=torch.tensor([entry['idx']]).unsqueeze(0)
#      90 )
#      92 return data
#
# KeyboardInterrupt:

# %% [markdown]
# # Painn

# %%
reverify_wandb_models(
    model_params={
        "struct_type": "unrelaxed",
        "model_type": "Painn",
        "training_fraction":1.0,
    },
    gpu_num=0
)

# %%
keep_the_best_few_models(
    model_params={
        "struct_type": "unrelaxed",
        "model_type": "Painn",
        "training_fraction":1.0,
    },
    num_best_models=3
)

# %% [markdown]
# # ALIGNN

# %%
reverify_wandb_models(
    model_params={
        "struct_type": "relaxed",
        "model_type": "ALIGNN",
        "training_fraction":0.125,
    },
    gpu_num=0
)
# Out:
# Loaded data
# Completed data processing
# 100%|██████████| 3111/3111 [00:00<00:00, 7306.75it/s]
# data range 1.5473600840000001 0.0
# Converting to graphs!
# 100%|██████████| 3111/3111 [00:45<00:00, 68.22it/s]
# /data/users/kritarth/PerovskiteOrderingGCNNs/models/PerovskiteOrderingGCNNs_alignn/alignn/graphs.py:958: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:275.)
#   self.lattices = torch.tensor(self.lattices).type(
# df               formula                       framework  \
# 0     Cr1La4Ni7O24Pr4  La0.500Pr0.500Cr0.125Ni0.875O3
# 1     Ac4Ba4O24Ru3Tc5  Ac0.500Ba0.500Ru0.375Tc0.625O3
# 2     Hf3Mn5O24Pb7Sr1  Pb0.875Sr0.125Hf0.375Mn0.625O3
# 3        Ca4Fe8O24Sr4              Ca0.500Sr0.500FeO3
# 4     Cr1La3O24Rb5Ru7  La0.375Rb0.625Cr0.125Ru0.875O3
# ...               ...                             ...
# 3106         O3Te1Zr1                          ZrTeO3
# 3107         O3Tl1Zr1                          ZrTlO3
# 3108          O3V1Zr1                           ZrVO3
# 3109          O3Y1Zr1                           ZrYO3
# 3110         O3Zn1Zr1                          ZrZnO3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Pr', 'La'], 'B': ['Ni', 'Cr'...                 40
# 1     {'sites': {'A': ['Ac', 'Ba'], 'B': ['Ru', 'Tc'...                 40
# 2     {'sites': {'A': ['Sr', 'Pb'], 'B': ['Hf', 'Mn'...                 40
# 3     {'sites': {'A': ['Sr', 'Ca'], 'B': ['Fe'], 'X'...                 40
# 4     {'sites': {'A': ['La', 'Rb'], 'B': ['Cr', 'Ru'...                 40
# ...                                                 ...                ...
# 3106  {'sites': {'A': ['Zr'], 'B': ['Te'], 'X': ['O'...                 40
# 3107  {'sites': {'A': ['Zr'], 'B': ['Tl'], 'X': ['O'...                 40
# 3108  {'sites': {'A': ['Zr'], 'B': ['V'], 'X': ['O']...                 40
# 3109  {'sites': {'A': ['Zr'], 'B': ['Y'], 'X': ['O']...                 40
# 3110  {'sites': {'A': ['Zr'], 'B': ['Zn'], 'X': ['O'...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           222996458
# 1              40           149371528
# 2              40           205328812
# 3              40           222997894
# 4              40           205327484
# ...           ...                 ...
# 3106           40           137459436
# 3107           40           137458818
# 3108           40           137458560
# 3109           40           137460704
# 3110           40           137460691
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     427514528
# 1     {'@module': 'pymatgen.core.structure', '@class...     429562277
# 2     {'@module': 'pymatgen.core.structure', '@class...     458313128
# 3     {'@module': 'pymatgen.core.structure', '@class...     428493961
# 4     {'@module': 'pymatgen.core.structure', '@class...     255169844
# ...                                                 ...           ...
# 3106  {'@module': 'pymatgen.core.structure', '@class...     472477145
# 3107  {'@module': 'pymatgen.core.structure', '@class...     472811076
# 3108  {'@module': 'pymatgen.core.structure', '@class...     452734370
# 3109  {'@module': 'pymatgen.core.structure', '@class...     467990988
# 3110  {'@module': 'pymatgen.core.structure', '@class...     472539926
#
#                                              opt_struct  es_job_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  123322811
# 1     {'@module': 'pymatgen.core.structure', '@class...  123777852
# 2     {'@module': 'pymatgen.core.structure', '@class...  125437062
# 3     {'@module': 'pymatgen.core.structure', '@class...  123744086
# 4     {'@module': 'pymatgen.core.structure', '@class...   73683918
# ...                                                 ...        ...
# 3106  {'@module': 'pymatgen.core.structure', '@class...  127179422
# 3107  {'@module': 'pymatgen.core.structure', '@class...  127268711
# 3108  {'@module': 'pymatgen.core.structure', '@class...  125403163
# 3109  {'@module': 'pymatgen.core.structure', '@class...  126849119
# 3110  {'@module': 'pymatgen.core.structure', '@class...  127202068
#
#       dft_energy  dft_energy_per_atom  dft_e_hull  Op_band_center  \
# 0    -269.429516            -6.735738    0.102901       -1.912445
# 1    -305.132412            -7.628310    0.056276       -3.734871
# 2    -284.495242            -7.112381    0.123631       -1.555486
# 3    -253.347368            -6.333684    0.061250       -1.356781
# 4    -273.835152            -6.845879    0.101305       -3.132304
# ...          ...                  ...         ...             ...
# 3106 -295.360238            -7.384006    0.252080       -3.400961
# 3107 -288.728572            -7.218214    0.211370       -1.599369
# 3108 -349.386755            -8.734669    0.142448       -4.228963
# 3109 -363.619517            -9.090488    0.204514       -4.738996
# 3110 -291.492909            -7.287323    0.235271       -1.762010
#
#                                               structure  \
# 0     [[1.95711997 5.84247324 5.82532761] Cr, [0.110...
# 1     [[-0.00653859  4.01092326  4.09318162] Ac, [4....
# 2     [[2.01054201 2.01439401 2.00782829] Hf, [1.996...
# 3     [[-0.00952458  3.73131081  3.86068654] Ca, [-7...
# 4     [[2.02354061 2.02354061 1.94173956] Cr, [0.028...
# ...                                                 ...
# 3106  [[1.00432997 1.89319247 1.44767751] O, [11.984...
# 3107  [[ 7.60672692 10.74011201 12.08354081] O, [8.8...
# 3108  [[1.14009548 2.38818437 0.05415575] O, [-0.237...
# 3109  [[ 1.15842677  3.26073654 -0.12368959] O, [0.3...
# 3110  [[1.36927661 2.71741204 0.03277304] O, [8.5317...
#
#                                           ase_structure   idx  \
# 0     (Atom('Cr', [1.9571199712589207, 5.84247324493...   227
# 1     (Atom('Ac', [-0.0065385917833841, 4.0109232623...  2291
# 2     (Atom('Hf', [2.010542007725679, 2.014394009859...  3303
# 3     (Atom('Ca', [-0.009524581722547, 3.73131081117...  2161
# 4     (Atom('Cr', [2.023540614200952, 2.023540614200...  2545
# ...                                                 ...   ...
# 3106  (Atom('O', [1.0043299735578444, 1.893192472481...  2654
# 3107  (Atom('O', [7.606726915778809, 10.740112006117...  2655
# 3108  (Atom('O', [1.1400954775738754, 2.388184368165...  2656
# 3109  (Atom('O', [1.158426768113408, 3.2607365413063...  2657
# 3110  (Atom('O', [1.3692766115361463, 2.717412043495...  2658
#
#                                                   atoms
# 0     {'elements': ['Cr', 'La', 'La', 'La', 'La', 'N...
# 1     {'elements': ['Ac', 'Ac', 'Ac', 'Ac', 'Ba', 'B...
# 2     {'elements': ['Hf', 'Hf', 'Hf', 'Mn', 'Mn', 'M...
# 3     {'elements': ['Ca', 'Ca', 'Ca', 'Ca', 'Fe', 'F...
# 4     {'elements': ['Cr', 'La', 'La', 'La', 'O', 'O'...
# ...                                                 ...
# 3106  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3107  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3108  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3109  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3110  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
#
# [3111 rows x 18 columns]
# warning: could not load CGCNN features for 103
# Setting it to max atomic number available here, 103
# warning: could not load CGCNN features for 101
# Setting it to max atomic number available here, 103
# warning: could not load CGCNN features for 102
# Setting it to max atomic number available here, 103
# building line graphs
# 100%|██████████| 3111/3111 [00:03<00:00, 1013.75it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 1277/1277 [00:00<00:00, 7101.17it/s]
# data range 0.7422469374 0.0
# Converting to graphs!
# 100%|██████████| 1277/1277 [00:21<00:00, 58.81it/s]
# df               formula                       framework  \
# 0     Ba3Ca5Co3Cr5O24  Ba0.375Ca0.625Co0.375Cr0.625O3
# 1     Ba3Ca5Co3Cr5O24  Ba0.375Ca0.625Co0.375Cr0.625O3
# 2     Ba3Ca5Co3Cr5O24  Ba0.375Ca0.625Co0.375Cr0.625O3
# 3     Ba3Ca5Co3Cr5O24  Ba0.375Ca0.625Co0.375Cr0.625O3
# 4     Ba5Ca3Cr2Mn6O24  Ba0.625Ca0.375Cr0.250Mn0.750O3
# ...               ...                             ...
# 1272     O24Re4Sr8Zn4              SrRe0.500Zn0.500O3
# 1273     O24Re4Sr8Zn4              SrRe0.500Zn0.500O3
# 1274     O24Re4Sr8Zn4              SrRe0.500Zn0.500O3
# 1275     O24Re4Sr8Zn4              SrRe0.500Zn0.500O3
# 1276     O24Re4Sr8Zn4              SrRe0.500Zn0.500O3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Ba', 'Ca'], 'B': ['Co', 'Cr'...                 40
# 1     {'sites': {'A': ['Ba', 'Ca'], 'B': ['Co', 'Cr'...                 40
# 2     {'sites': {'A': ['Ba', 'Ca'], 'B': ['Co', 'Cr'...                 40
# 3     {'sites': {'A': ['Ba', 'Ca'], 'B': ['Co', 'Cr'...                 40
# 4     {'sites': {'A': ['Ba', 'Ca'], 'B': ['Cr', 'Mn'...                 40
# ...                                                 ...                ...
# 1272  {'sites': {'A': ['Sr'], 'B': ['Zn', 'Re'], 'X'...                 40
# 1273  {'sites': {'A': ['Sr'], 'B': ['Zn', 'Re'], 'X'...                 40
# 1274  {'sites': {'A': ['Sr'], 'B': ['Zn', 'Re'], 'X'...                 40
# 1275  {'sites': {'A': ['Sr'], 'B': ['Zn', 'Re'], 'X'...                 40
# 1276  {'sites': {'A': ['Sr'], 'B': ['Zn', 'Re'], 'X'...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           222996443
# 1              40           222996442
# 2              40           222996441
# 3              40           222996440
# 4              40           222996473
# ...           ...                 ...
# 1272           40           261448647
# 1273           40           261448648
# 1274           40           261448649
# 1275           40           261448650
# 1276           40           261448646
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     419905252
# 1     {'@module': 'pymatgen.core.structure', '@class...     419905110
# 2     {'@module': 'pymatgen.core.structure', '@class...     421255716
# 3     {'@module': 'pymatgen.core.structure', '@class...     421255708
# 4     {'@module': 'pymatgen.core.structure', '@class...     423959361
# ...                                                 ...           ...
# 1272  {'@module': 'pymatgen.core.structure', '@class...     421446401
# 1273  {'@module': 'pymatgen.core.structure', '@class...     421467803
# 1274  {'@module': 'pymatgen.core.structure', '@class...     421446386
# 1275  {'@module': 'pymatgen.core.structure', '@class...     421467806
# 1276  {'@module': 'pymatgen.core.structure', '@class...     421467809
#
#                                              opt_struct  es_job_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  122914535
# 1     {'@module': 'pymatgen.core.structure', '@class...  122894568
# 2     {'@module': 'pymatgen.core.structure', '@class...  122946762
# 3     {'@module': 'pymatgen.core.structure', '@class...  122946757
# 4     {'@module': 'pymatgen.core.structure', '@class...  123103527
# ...                                                 ...        ...
# 1272  {'@module': 'pymatgen.core.structure', '@class...  122979156
# 1273  {'@module': 'pymatgen.core.structure', '@class...  122979555
# 1274  {'@module': 'pymatgen.core.structure', '@class...  122979602
# 1275  {'@module': 'pymatgen.core.structure', '@class...  122979556
# 1276  {'@module': 'pymatgen.core.structure', '@class...  122979558
#
#       dft_energy  dft_energy_per_atom  dft_e_hull  Op_band_center  \
# 0    -263.534848            -6.588371    0.202469       -1.758032
# 1    -263.295035            -6.582376    0.208464       -1.924296
# 2    -263.852922            -6.596323    0.194517       -1.915962
# 3    -263.664789            -6.591620    0.199220       -2.048439
# 4    -272.711743            -6.817794    0.180146       -1.655282
# ...          ...                  ...         ...             ...
# 1272 -269.369506            -6.734238    0.131478       -3.212984
# 1273 -270.470094            -6.761752    0.103963       -3.209081
# 1274 -270.177140            -6.754428    0.111287       -3.098047
# 1275 -271.801151            -6.795029    0.070687       -3.398292
# 1276 -269.539550            -6.738489    0.127227       -3.024261
#
#                                               structure  \
# 0     [[5.86128784 5.74288481 5.85083339] Ba, [5.842...
# 1     [[ 0.03315806  7.73056998 -0.04206412] Ba, [0....
# 2     [[0.05031546 0.01889438 0.01435607] Ba, [0.059...
# 3     [[5.89554962 6.1991535  5.6482414 ] Ba, [5.825...
# 4     [[5.95038311 2.02702033 1.99031315] Ba, [2.029...
# ...                                                 ...
# 1272  [[7.74867591 4.42380437 1.99377219] O, [6.2232...
# 1273  [[-0.21604314  4.08943931  1.97508443] O, [6.4...
# 1274  [[0.27592504 4.21399605 5.90065469] O, [ 6.571...
# 1275  [[0.18218497 7.77176186 2.0931313 ] O, [6.0975...
# 1276  [[0.11717253 4.26574997 1.98568445] O, [6.1796...
#
#                                           ase_structure   idx  \
# 0     (Atom('Ba', [5.861287837647459, 5.742884809559...     0
# 1     (Atom('Ba', [0.033158063186773806, 7.730569982...     1
# 2     (Atom('Ba', [0.050315461923659606, 0.018894375...     2
# 3     (Atom('Ba', [5.895549619832608, 6.199153500740...     3
# 4     (Atom('Ba', [5.950383110572555, 2.027020332513...     4
# ...                                                 ...   ...
# 1272  (Atom('O', [7.748675906615044, 4.4238043670199...  1272
# 1273  (Atom('O', [-0.21604313613176382, 4.0894393125...  1273
# 1274  (Atom('O', [0.2759250385470491, 4.213996052684...  1274
# 1275  (Atom('O', [0.1821849738552257, 7.771761862807...  1275
# 1276  (Atom('O', [0.11717253224978941, 4.26574996606...  1276
#
#                                                   atoms
# 0     {'elements': ['Ba', 'Ba', 'Ba', 'Ca', 'Ca', 'C...
# 1     {'elements': ['Ba', 'Ba', 'Ba', 'Ca', 'Ca', 'C...
# 2     {'elements': ['Ba', 'Ba', 'Ba', 'Ca', 'Ca', 'C...
# 3     {'elements': ['Ba', 'Ba', 'Ba', 'Ca', 'Ca', 'C...
# 4     {'elements': ['Ba', 'Ba', 'Ba', 'Ba', 'Ba', 'C...
# ...                                                 ...
# 1272  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 1273  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 1274  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 1275  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 1276  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
#
# [1277 rows x 18 columns]
# building line graphs
# 100%|██████████| 1277/1277 [00:01<00:00, 1129.68it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# Reverifying wandb model #0 (observ_12mfnos9)
# 100%|██████████| 3111/3111 [00:12<00:00, 243.69it/s]
# /data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \
# Reverifying wandb model #1 (observ_257ayt77)
# 100%|██████████| 3111/3111 [00:03<00:00, 1027.69it/s]
# Reverifying wandb model #2 (observ_2z10gxfz)
# 100%|██████████| 3111/3111 [00:08<00:00, 349.26it/s]
# Reverifying wandb model #3 (observ_3bff7deo)
# 100%|██████████| 3111/3111 [00:05<00:00, 543.82it/s]
# Reverifying wandb model #4 (observ_3gq7379k)
# 100%|██████████| 3111/3111 [00:06<00:00, 513.49it/s]
# Reverifying wandb model #5 (observ_3r3sz910)
# 100%|██████████| 3111/3111 [00:12<00:00, 249.64it/s]
# Reverifying wandb model #6 (observ_4acec0fx)
# 100%|██████████| 3111/3111 [00:03<00:00, 1027.16it/s]
# Reverifying wandb model #7 (observ_5eus5trf)
# 100%|██████████| 3111/3111 [00:08<00:00, 364.32it/s]
# Reverifying wandb model #8 (observ_6267ntfa)
# 100%|██████████| 3111/3111 [00:08<00:00, 379.85it/s]
# Reverifying wandb model #9 (observ_73i6pyzb)
# 100%|██████████| 3111/3111 [00:03<00:00, 841.97it/s]
# Reverifying wandb model #10 (observ_9j17b73w)
# 100%|██████████| 3111/3111 [00:11<00:00, 280.53it/s]
# Reverifying wandb model #11 (observ_9m4b3ymh)
# 100%|██████████| 3111/3111 [00:03<00:00, 1017.38it/s]
# Reverifying wandb model #12 (observ_a3783f7g)
# 100%|██████████| 3111/3111 [00:07<00:00, 425.08it/s]
# Reverifying wandb model #13 (observ_a3ztdtyf)
# 100%|██████████| 3111/3111 [00:10<00:00, 292.50it/s]
# Reverifying wandb model #14 (observ_acxi0gsz)
# 100%|██████████| 3111/3111 [00:03<00:00, 911.61it/s]
# Reverifying wandb model #15 (observ_b76rpbgv)
# 100%|██████████| 3111/3111 [00:12<00:00, 255.73it/s]
# Reverifying wandb model #16 (observ_bj12zkwd)
# 100%|██████████| 3111/3111 [00:03<00:00, 1029.61it/s]
# Reverifying wandb model #17 (observ_cd40mcpv)
# 100%|██████████| 3111/3111 [00:07<00:00, 399.98it/s]
# Reverifying wandb model #18 (observ_dcnm9i52)
# 100%|██████████| 3111/3111 [00:08<00:00, 345.95it/s]
# Reverifying wandb model #19 (observ_ffl0b1cj)
# 100%|██████████| 3111/3111 [00:03<00:00, 845.46it/s]
# Reverifying wandb model #20 (observ_flwhw8zc)
# 100%|██████████| 3111/3111 [00:12<00:00, 251.15it/s]
# Reverifying wandb model #21 (observ_fn6q90oc)
# 100%|██████████| 3111/3111 [00:03<00:00, 1028.21it/s]
# Reverifying wandb model #22 (observ_fpako7a4)
# 100%|██████████| 3111/3111 [00:08<00:00, 382.33it/s]
# Reverifying wandb model #23 (observ_fzbg5a60)
# 100%|██████████| 3111/3111 [00:08<00:00, 381.82it/s]
# Reverifying wandb model #24 (observ_g6242vkx)
# 100%|██████████| 3111/3111 [00:04<00:00, 723.32it/s]
# Reverifying wandb model #25 (observ_gihmko99)
# 100%|██████████| 3111/3111 [00:12<00:00, 250.12it/s]
# Reverifying wandb model #26 (observ_gm38ecqu)
# 100%|██████████| 3111/3111 [00:03<00:00, 1030.46it/s]
# Reverifying wandb model #27 (observ_gx2kdpah)
# 100%|██████████| 3111/3111 [00:08<00:00, 363.49it/s]
# Reverifying wandb model #28 (observ_h9s6zugx)
# 100%|██████████| 3111/3111 [00:07<00:00, 411.13it/s]
# Reverifying wandb model #29 (observ_hf9oe5eo)
# 100%|██████████| 3111/3111 [00:04<00:00, 634.38it/s]
# Reverifying wandb model #30 (observ_hfgeoy2l)
# 100%|██████████| 3111/3111 [00:12<00:00, 248.52it/s]
# Reverifying wandb model #31 (observ_idd0kvz2)
# 100%|██████████| 3111/3111 [00:03<00:00, 1027.71it/s]
# Reverifying wandb model #32 (observ_jmutnpeg)
# 100%|██████████| 3111/3111 [00:09<00:00, 341.05it/s]
# Reverifying wandb model #33 (observ_jos0b52x)
# 100%|██████████| 3111/3111 [00:07<00:00, 444.34it/s]
# Reverifying wandb model #34 (observ_lf21s8hn)
# 100%|██████████| 3111/3111 [00:05<00:00, 598.13it/s]
# Reverifying wandb model #35 (observ_m3gbxlol)
# 100%|██████████| 3111/3111 [00:12<00:00, 250.49it/s]
# Reverifying wandb model #36 (observ_mv0fdokd)
# 100%|██████████| 3111/3111 [00:03<00:00, 1032.10it/s]
# Reverifying wandb model #37 (observ_oxoxgwm3)
# 100%|██████████| 3111/3111 [00:09<00:00, 325.38it/s]
# Reverifying wandb model #38 (observ_p31ucwlv)
# 100%|██████████| 3111/3111 [00:05<00:00, 613.11it/s]
# Reverifying wandb model #39 (observ_q02ebqce)
# 100%|██████████| 3111/3111 [00:06<00:00, 465.97it/s]
# Reverifying wandb model #40 (observ_qk3fuqzc)
# 100%|██████████| 3111/3111 [00:12<00:00, 252.20it/s]
# Reverifying wandb model #41 (observ_qwftd5lv)
# 100%|██████████| 3111/3111 [00:03<00:00, 1027.61it/s]
# Reverifying wandb model #42 (observ_rpx0vcgg)
# 100%|██████████| 3111/3111 [00:10<00:00, 298.01it/s]
# Reverifying wandb model #43 (observ_t1sphl7r)
# 100%|██████████| 3111/3111 [00:04<00:00, 688.31it/s]
# Reverifying wandb model #44 (observ_ty5b6yot)
# 100%|██████████| 3111/3111 [00:06<00:00, 471.29it/s]
# Reverifying wandb model #45 (observ_u3gneg61)
# 100%|██████████| 3111/3111 [00:12<00:00, 249.87it/s]
# Reverifying wandb model #46 (observ_vbk7zq7h)
# 100%|██████████| 3111/3111 [00:03<00:00, 1029.66it/s]
# Reverifying wandb model #47 (observ_vedq1ie6)
# 100%|██████████| 3111/3111 [00:10<00:00, 306.87it/s]
# Reverifying wandb model #48 (observ_xj4g5hn4)
# 100%|██████████| 3111/3111 [00:04<00:00, 669.75it/s]

# %%
keep_the_best_few_models(
    model_params={
        "struct_type": "relaxed",
        "model_type": "ALIGNN",
        "training_fraction":0.125,
    },
    num_best_models=3
)

# %%
get_all_model_predictions(
    model_params={
        "struct_type": "relaxed",
        "model_type": "ALIGNN",
        "training_fraction":0.125,
    },
    gpu_num=0,
    num_best_models=3
)
# Out:
# Loaded data
# Completed data processing
# 100%|██████████| 3111/3111 [00:00<00:00, 7290.96it/s]
# data range 1.5473600840000001 0.0
# Converting to graphs!
# 100%|██████████| 3111/3111 [00:46<00:00, 67.55it/s]
# df               formula                       framework  \
# 0     Cr1La4Ni7O24Pr4  La0.500Pr0.500Cr0.125Ni0.875O3
# 1     Ac4Ba4O24Ru3Tc5  Ac0.500Ba0.500Ru0.375Tc0.625O3
# 2     Hf3Mn5O24Pb7Sr1  Pb0.875Sr0.125Hf0.375Mn0.625O3
# 3        Ca4Fe8O24Sr4              Ca0.500Sr0.500FeO3
# 4     Cr1La3O24Rb5Ru7  La0.375Rb0.625Cr0.125Ru0.875O3
# ...               ...                             ...
# 3106         O3Te1Zr1                          ZrTeO3
# 3107         O3Tl1Zr1                          ZrTlO3
# 3108          O3V1Zr1                           ZrVO3
# 3109          O3Y1Zr1                           ZrYO3
# 3110         O3Zn1Zr1                          ZrZnO3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Pr', 'La'], 'B': ['Ni', 'Cr'...                 40
# 1     {'sites': {'A': ['Ac', 'Ba'], 'B': ['Ru', 'Tc'...                 40
# 2     {'sites': {'A': ['Sr', 'Pb'], 'B': ['Hf', 'Mn'...                 40
# 3     {'sites': {'A': ['Sr', 'Ca'], 'B': ['Fe'], 'X'...                 40
# 4     {'sites': {'A': ['La', 'Rb'], 'B': ['Cr', 'Ru'...                 40
# ...                                                 ...                ...
# 3106  {'sites': {'A': ['Zr'], 'B': ['Te'], 'X': ['O'...                 40
# 3107  {'sites': {'A': ['Zr'], 'B': ['Tl'], 'X': ['O'...                 40
# 3108  {'sites': {'A': ['Zr'], 'B': ['V'], 'X': ['O']...                 40
# 3109  {'sites': {'A': ['Zr'], 'B': ['Y'], 'X': ['O']...                 40
# 3110  {'sites': {'A': ['Zr'], 'B': ['Zn'], 'X': ['O'...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           222996458
# 1              40           149371528
# 2              40           205328812
# 3              40           222997894
# 4              40           205327484
# ...           ...                 ...
# 3106           40           137459436
# 3107           40           137458818
# 3108           40           137458560
# 3109           40           137460704
# 3110           40           137460691
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     427514528
# 1     {'@module': 'pymatgen.core.structure', '@class...     429562277
# 2     {'@module': 'pymatgen.core.structure', '@class...     458313128
# 3     {'@module': 'pymatgen.core.structure', '@class...     428493961
# 4     {'@module': 'pymatgen.core.structure', '@class...     255169844
# ...                                                 ...           ...
# 3106  {'@module': 'pymatgen.core.structure', '@class...     472477145
# 3107  {'@module': 'pymatgen.core.structure', '@class...     472811076
# 3108  {'@module': 'pymatgen.core.structure', '@class...     452734370
# 3109  {'@module': 'pymatgen.core.structure', '@class...     467990988
# 3110  {'@module': 'pymatgen.core.structure', '@class...     472539926
#
#                                              opt_struct  es_job_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  123322811
# 1     {'@module': 'pymatgen.core.structure', '@class...  123777852
# 2     {'@module': 'pymatgen.core.structure', '@class...  125437062
# 3     {'@module': 'pymatgen.core.structure', '@class...  123744086
# 4     {'@module': 'pymatgen.core.structure', '@class...   73683918
# ...                                                 ...        ...
# 3106  {'@module': 'pymatgen.core.structure', '@class...  127179422
# 3107  {'@module': 'pymatgen.core.structure', '@class...  127268711
# 3108  {'@module': 'pymatgen.core.structure', '@class...  125403163
# 3109  {'@module': 'pymatgen.core.structure', '@class...  126849119
# 3110  {'@module': 'pymatgen.core.structure', '@class...  127202068
#
#       dft_energy  dft_energy_per_atom  dft_e_hull  Op_band_center  \
# 0    -269.429516            -6.735738    0.102901       -1.912445
# 1    -305.132412            -7.628310    0.056276       -3.734871
# 2    -284.495242            -7.112381    0.123631       -1.555486
# 3    -253.347368            -6.333684    0.061250       -1.356781
# 4    -273.835152            -6.845879    0.101305       -3.132304
# ...          ...                  ...         ...             ...
# 3106 -295.360238            -7.384006    0.252080       -3.400961
# 3107 -288.728572            -7.218214    0.211370       -1.599369
# 3108 -349.386755            -8.734669    0.142448       -4.228963
# 3109 -363.619517            -9.090488    0.204514       -4.738996
# 3110 -291.492909            -7.287323    0.235271       -1.762010
#
#                                               structure  \
# 0     [[1.95711997 5.84247324 5.82532761] Cr, [0.110...
# 1     [[-0.00653859  4.01092326  4.09318162] Ac, [4....
# 2     [[2.01054201 2.01439401 2.00782829] Hf, [1.996...
# 3     [[-0.00952458  3.73131081  3.86068654] Ca, [-7...
# 4     [[2.02354061 2.02354061 1.94173956] Cr, [0.028...
# ...                                                 ...
# 3106  [[1.00432997 1.89319247 1.44767751] O, [11.984...
# 3107  [[ 7.60672692 10.74011201 12.08354081] O, [8.8...
# 3108  [[1.14009548 2.38818437 0.05415575] O, [-0.237...
# 3109  [[ 1.15842677  3.26073654 -0.12368959] O, [0.3...
# 3110  [[1.36927661 2.71741204 0.03277304] O, [8.5317...
#
#                                           ase_structure   idx  \
# 0     (Atom('Cr', [1.9571199712589207, 5.84247324493...   227
# 1     (Atom('Ac', [-0.0065385917833841, 4.0109232623...  2291
# 2     (Atom('Hf', [2.010542007725679, 2.014394009859...  3303
# 3     (Atom('Ca', [-0.009524581722547, 3.73131081117...  2161
# 4     (Atom('Cr', [2.023540614200952, 2.023540614200...  2545
# ...                                                 ...   ...
# 3106  (Atom('O', [1.0043299735578444, 1.893192472481...  2654
# 3107  (Atom('O', [7.606726915778809, 10.740112006117...  2655
# 3108  (Atom('O', [1.1400954775738754, 2.388184368165...  2656
# 3109  (Atom('O', [1.158426768113408, 3.2607365413063...  2657
# 3110  (Atom('O', [1.3692766115361463, 2.717412043495...  2658
#
#                                                   atoms
# 0     {'elements': ['Cr', 'La', 'La', 'La', 'La', 'N...
# 1     {'elements': ['Ac', 'Ac', 'Ac', 'Ac', 'Ba', 'B...
# 2     {'elements': ['Hf', 'Hf', 'Hf', 'Mn', 'Mn', 'M...
# 3     {'elements': ['Ca', 'Ca', 'Ca', 'Ca', 'Fe', 'F...
# 4     {'elements': ['Cr', 'La', 'La', 'La', 'O', 'O'...
# ...                                                 ...
# 3106  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3107  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3108  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3109  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
# 3110  {'elements': ['O', 'O', 'O', 'O', 'O', 'O', 'O...
#
# [3111 rows x 18 columns]
# building line graphs
# 100%|██████████| 3111/3111 [00:03<00:00, 918.45it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 1261/1261 [00:00<00:00, 7129.36it/s]
# data range 0.44672706030000003 0.0
# Converting to graphs!
# 100%|██████████| 1261/1261 [00:21<00:00, 59.87it/s]
# df               formula                       framework  \
# 0     Ba2Cr4Mn4O24Pr6  Ba0.250Pr0.750Cr0.500Mn0.500O3
# 1     Ba2Cr4Mn4O24Pr6  Ba0.250Pr0.750Cr0.500Mn0.500O3
# 2     Ba2Fe4Ni4O24Pr6  Ba0.250Pr0.750Fe0.500Ni0.500O3
# 3     Ba2Fe4Ni4O24Pr6  Ba0.250Pr0.750Fe0.500Ni0.500O3
# 4     Ba3Ca5Co1Ni7O24  Ba0.375Ca0.625Co0.125Ni0.875O3
# ...               ...                             ...
# 1256      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1257      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1258      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1259      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1260      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Ba', 'Pr'], 'B': ['Cr', 'Mn'...                 40
# 1     {'sites': {'A': ['Ba', 'Pr'], 'B': ['Cr', 'Mn'...                 40
# 2     {'sites': {'A': ['Pr', 'Ba'], 'B': ['Fe', 'Ni'...                 40
# 3     {'sites': {'A': ['Pr', 'Ba'], 'B': ['Fe', 'Ni'...                 40
# 4     {'sites': {'A': ['Ba', 'Ca'], 'B': ['Co', 'Ni'...                 40
# ...                                                 ...                ...
# 1256  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1257  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1258  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1259  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1260  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           200879856
# 1              40           201883019
# 2              40           222996848
# 3              40           222996849
# 4              40           222996910
# ...           ...                 ...
# 1256           40           272062453
# 1257           40           272062454
# 1258           40           272062455
# 1259           40           272062457
# 1260           40           272062456
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     419905109
# 1     {'@module': 'pymatgen.core.structure', '@class...     423959303
# 2     {'@module': 'pymatgen.core.structure', '@class...     419905248
# 3     {'@module': 'pymatgen.core.structure', '@class...     420168914
# 4     {'@module': 'pymatgen.core.structure', '@class...     419905120
# ...                                                 ...           ...
# 1256  {'@module': 'pymatgen.core.structure', '@class...     421466164
# 1257  {'@module': 'pymatgen.core.structure', '@class...     421562098
# 1258  {'@module': 'pymatgen.core.structure', '@class...     421466146
# 1259  {'@module': 'pymatgen.core.structure', '@class...     421446133
# 1260  {'@module': 'pymatgen.core.structure', '@class...     421448171
#
#                                              opt_struct  es_job_id  ...  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  122894567  ...
# 1     {'@module': 'pymatgen.core.structure', '@class...  123103478  ...
# 2     {'@module': 'pymatgen.core.structure', '@class...  122894599  ...
# 3     {'@module': 'pymatgen.core.structure', '@class...  122914674  ...
# 4     {'@module': 'pymatgen.core.structure', '@class...  122894577  ...
# ...                                                 ...        ...  ...
# 1256  {'@module': 'pymatgen.core.structure', '@class...  122979645  ...
# 1257  {'@module': 'pymatgen.core.structure', '@class...  122988181  ...
# 1258  {'@module': 'pymatgen.core.structure', '@class...  122979642  ...
# 1259  {'@module': 'pymatgen.core.structure', '@class...  122979075  ...
# 1260  {'@module': 'pymatgen.core.structure', '@class...  122979218  ...
#
#       M3Gnet_relaxed_energy_per_atom  CHGNet_relaxed_energy  \
# 0                          -7.729604            -341.100922
# 1                          -7.743665            -341.377296
# 2                          -6.695003            -302.698708
# 3                          -6.711643            -303.274498
# 4                          -5.364596            -249.942665
# ...                              ...                    ...
# 1256                       -7.698078            -330.600357
# 1257                       -7.683108            -331.823959
# 1258                       -7.707710            -332.275696
# 1259                       -7.682349            -332.135582
# 1260                       -7.677264            -330.988693
#
#       CHGNet_energy_correction  CHGNet_relaxed_energy_per_atom_corrected  \
# 0                      -31.156                                 -7.748623
# 1                      -31.156                                 -7.755532
# 2                      -35.676                                 -6.675568
# 3                      -35.676                                 -6.689962
# 4                      -35.913                                 -5.350742
# ...                        ...                                       ...
# 1256                   -23.160                                 -7.686009
# 1257                   -23.160                                 -7.716599
# 1258                   -23.160                                 -7.727892
# 1259                   -23.160                                 -7.724390
# 1260                   -23.160                                 -7.695717
#
#       MACE_relaxed_energy  MACE_relaxed_energy_per_atom  \
# 0             -310.140472                     -7.753512
# 1             -310.617950                     -7.765449
# 2             -268.719086                     -6.717977
# 3             -269.109955                     -6.727749
# 4             -215.761551                     -5.394039
# ...                   ...                           ...
# 1256          -309.514526                     -7.737863
# 1257          -309.492981                     -7.737325
# 1258          -309.585693                     -7.739642
# 1259          -309.614899                     -7.740372
# 1260          -309.509247                     -7.737731
#
#                                               structure  \
# 0     [[-0.02984121 -0.0203263   8.01287465] Ba, [-0...
# 1     [[-0.06088744 -0.00427603 -0.01710486] Ba, [0....
# 2     [[-0.0005967   0.03938371  0.06173621] Ba, [-2...
# 3     [[-2.50217530e-02  7.84618079e+00  4.93222087e...
# 4     [[7.74303178 7.75218255 7.80966426] Ba, [-0.00...
# ...                                                 ...
# 1256  [[0.00570504 0.00061555 0.00431329] Cu, [3.906...
# 1257  [[ 0.00085972  0.00614957 -0.001863  ] Cu, [3....
# 1258  [[-0.00872743  0.00534212 -0.00188023] Cu, [4....
# 1259  [[ 0.00844437  0.00115989 -0.0051131 ] Cu, [0....
# 1260  [[ 0.00036137 -0.00203896  0.00223046] Cu, [-4...
#
#                                           ase_structure   idx  \
# 0     (Atom('Ba', [-0.0298412098217056, -0.020326301...     0
# 1     (Atom('Ba', [-0.0608874364491038, -0.004276030...     1
# 2     (Atom('Ba', [-0.0005966979882694001, 0.0393837...     2
# 3     (Atom('Ba', [-0.025021752975726598, 7.84618079...     3
# 4     (Atom('Ba', [7.743031778764101, 7.752182547421...     4
# ...                                                 ...   ...
# 1256  (Atom('Cu', [0.0057050416247932, 0.00061554706...  1256
# 1257  (Atom('Cu', [0.0008597211189909, 0.00614956671...  1257
# 1258  (Atom('Cu', [-0.0087274276058126, 0.0053421229...  1258
# 1259  (Atom('Cu', [0.0084443681982426, 0.00115988897...  1259
# 1260  (Atom('Cu', [0.00036137385466499997, -0.002038...  1260
#
#                                                   atoms
# 0     {'elements': ['Ba', 'Ba', 'Cr', 'Cr', 'Cr', 'C...
# 1     {'elements': ['Ba', 'Ba', 'Cr', 'Cr', 'Cr', 'C...
# 2     {'elements': ['Ba', 'Ba', 'Fe', 'Fe', 'Fe', 'F...
# 3     {'elements': ['Ba', 'Ba', 'Fe', 'Fe', 'Fe', 'F...
# 4     {'elements': ['Ba', 'Ba', 'Ba', 'Ca', 'Ca', 'C...
# ...                                                 ...
# 1256  {'elements': ['Cu', 'Cu', 'Cu', 'Cu', 'Mn', 'M...
# 1257  {'elements': ['Cu', 'Cu', 'Cu', 'Cu', 'Mn', 'M...
# 1258  {'elements': ['Cu', 'Cu', 'Cu', 'Cu', 'Mn', 'M...
# 1259  {'elements': ['Cu', 'Cu', 'Cu', 'Cu', 'Mn', 'M...
# 1260  {'elements': ['Cu', 'Cu', 'Cu', 'Cu', 'Mn', 'M...
#
# [1261 rows x 25 columns]
# building line graphs
# 100%|██████████| 1261/1261 [00:01<00:00, 1119.35it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_all_model_predictions(
#       2     model_params={
#       3         "struct_type": "relaxed",
#       4         "model_type": "ALIGNN",
#       5         "training_fraction":0.125,
#       6     },
#       7     gpu_num=0,
#       8     num_best_models=3
#       9 )
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/inference/test_model_prediction.py:27, in get_all_model_predictions(model_params, gpu_num, target_prop, num_best_models)
#      24 model_params["long_range"] = False
#      26 for test_set_type in ["test_set", "holdout_set_B_sites", "holdout_set_series"]:
# ---> 27     get_model_prediction(test_set_type, model_params, gpu_num, target_prop, num_best_models)
#      28     print("Completed model prediction for " + test_set_type)
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/inference/test_model_prediction.py:115, in get_model_prediction(test_set_type, model_params, gpu_num, target_prop, num_best_models)
#     112 for idx in range(num_best_models):
#     113     # Updated directory structure: no exp_id in path
#     114     directory = "./best_models/" + model_params["model_type"] + "/" + wandb_name + "/" + "best_" + str(idx)
# --> 115     model, normalizer = load_model(gpu_num, train_loader, model_params, directory, target_prop,per_site=per_site)
#     116     start_3 = time.time()
#     117     prediction = evaluate_model_with_tracked_ids(model, normalizer, gpu_num, test_loader, model_params)
#
# File /data/users/kritarth/PerovskiteOrderingGCNNs/inference/test_model_prediction.py:149, in load_model(gpu_num, train_loader, model_params, directory, target_prop, per_site)
#     147     normalizer = None
#     148 else:
# --> 149     with open(directory + "/hyperparameters.json") as json_file:
#     150             assignments = json.load(json_file)
#     151     model, normalizer = create_model(model_params["model_type"], train_loader,model_params["interpolation"],target_prop,hyperparameters=assignments,per_site=per_site)
#
# FileNotFoundError: [Errno 2] No such file or directory: './best_models/ALIGNN/dft_e_hull_htvs_data_relaxed_ALIGNN_TrainingFraction0.125/best_0/hyperparameters.json'

# %%
get_all_embeddings(
    model_params={
        "struct_type": "relaxed",
        "model_type": "ALIGNN",
        "training_fraction":0.125,
    }, * 
    gpu_num=0,
    num_best_models=3
)
# Out:
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8985.10it/s]
# data range 1.5473600840000001 0.0
# Converting to graphs!
# 100%|██████████| 6276/6276 [01:31<00:00, 68.30it/s]
# df               formula                       framework  \
# 0     Cr1La4Ni7O24Pr4  La0.500Pr0.500Cr0.125Ni0.875O3
# 1     Ac4Ba4O24Ru3Tc5  Ac0.500Ba0.500Ru0.375Tc0.625O3
# 2     Hf3Mn5O24Pb7Sr1  Pb0.875Sr0.125Hf0.375Mn0.625O3
# 3        Ca4Fe8O24Sr4              Ca0.500Sr0.500FeO3
# 4     Cr1La3O24Rb5Ru7  La0.375Rb0.625Cr0.125Ru0.875O3
# ...               ...                             ...
# 6271         O3Te1Zr1                          ZrTeO3
# 6272         O3Tl1Zr1                          ZrTlO3
# 6273          O3V1Zr1                           ZrVO3
# 6274          O3Y1Zr1                           ZrYO3
# 6275         O3Zn1Zr1                          ZrZnO3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Pr', 'La'], 'B': ['Ni', 'Cr'...                 40
# 1     {'sites': {'A': ['Ac', 'Ba'], 'B': ['Ru', 'Tc'...                 40
# 2     {'sites': {'A': ['Sr', 'Pb'], 'B': ['Hf', 'Mn'...                 40
# 3     {'sites': {'A': ['Sr', 'Ca'], 'B': ['Fe'], 'X'...                 40
# 4     {'sites': {'A': ['La', 'Rb'], 'B': ['Cr', 'Ru'...                 40
# ...                                                 ...                ...
# 6271  {'sites': {'A': ['Zr'], 'B': ['Te'], 'X': ['O'...                 40
# 6272  {'sites': {'A': ['Zr'], 'B': ['Tl'], 'X': ['O'...                 40
# 6273  {'sites': {'A': ['Zr'], 'B': ['V'], 'X': ['O']...                 40
# 6274  {'sites': {'A': ['Zr'], 'B': ['Y'], 'X': ['O']...                 40
# 6275  {'sites': {'A': ['Zr'], 'B': ['Zn'], 'X': ['O'...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           222996458
# 1              40           149371528
# 2              40           205328812
# 3              40           222997894
# 4              40           205327484
# ...           ...                 ...
# 6271           40           137459436
# 6272           40           137458818
# 6273           40           137458560
# 6274           40           137460704
# 6275           40           137460691
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     427514528
# 1     {'@module': 'pymatgen.core.structure', '@class...     429562277
# 2     {'@module': 'pymatgen.core.structure', '@class...     458313128
# 3     {'@module': 'pymatgen.core.structure', '@class...     428493961
# 4     {'@module': 'pymatgen.core.structure', '@class...     255169844
# ...                                                 ...           ...
# 6271  {'@module': 'pymatgen.core.structure', '@class...     472477145
# 6272  {'@module': 'pymatgen.core.structure', '@class...     472811076
# 6273  {'@module': 'pymatgen.core.structure', '@class...     452734370
# 6274  {'@module': 'pymatgen.core.structure', '@class...     467990988
# 6275  {'@module': 'pymatgen.core.structure', '@class...     472539926
#
#                                              opt_struct  es_job_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  123322811
# 1     {'@module': 'pymatgen.core.structure', '@class...  123777852
# 2     {'@module': 'pymatgen.core.structure', '@class...  125437062
# 3     {'@module': 'pymatgen.core.structure', '@class...  123744086
# 4     {'@module': 'pymatgen.core.structure', '@class...   73683918
# ...                                                 ...        ...
# 6271  {'@module': 'pymatgen.core.structure', '@class...  127179422
# 6272  {'@module': 'pymatgen.core.structure', '@class...  127268711
# 6273  {'@module': 'pymatgen.core.structure', '@class...  125403163
# 6274  {'@module': 'pymatgen.core.structure', '@class...  126849119
# 6275  {'@module': 'pymatgen.core.structure', '@class...  127202068
#
#       dft_energy  dft_energy_per_atom  dft_e_hull  Op_band_center  \
# 0    -269.429516            -6.735738    0.102901       -1.912445
# 1    -305.132412            -7.628310    0.056276       -3.734871
# 2    -284.495242            -7.112381    0.123631       -1.555486
# 3    -253.347368            -6.333684    0.061250       -1.356781
# 4    -273.835152            -6.845879    0.101305       -3.132304
# ...          ...                  ...         ...             ...
# 6271 -295.360238            -7.384006    0.252080       -3.400961
# 6272 -288.728572            -7.218214    0.211370       -1.599369
# 6273 -349.386755            -8.734669    0.142448       -4.228963
# 6274 -363.619517            -9.090488    0.204514       -4.738996
# 6275 -291.492909            -7.287323    0.235271       -1.762010
#
#                                               structure  \
# 0     [[8.000000e-06 4.000008e+00 4.000008e+00] La, ...
# 1     [[0. 0. 0.] Ba, [0. 0. 4.] Ba, [0.0000000e+00 ...
# 2     [[8.e-06 8.e-06 8.e-06] Sr, [2.000008 2.000008...
# 3     [[8.000000e-06 4.000008e+00 4.000008e+00] Ca, ...
# 4     [[8.e-06 8.e-06 8.e-06] La, [2.000008 2.000008...
# ...                                                 ...
# 6271  [[0. 0. 0.] Zr, [2. 2. 2.] Te, [2. 2. 0.] O, [...
# 6272  [[0. 0. 0.] Zr, [2. 2. 2.] Tl, [2. 2. 0.] O, [...
# 6273  [[0. 0. 0.] Zr, [2. 2. 2.] V, [2. 2. 0.] O, [0...
# 6274  [[0. 0. 0.] Zr, [2. 2. 2.] Y, [2. 2. 0.] O, [0...
# 6275  [[0. 0. 0.] Zr, [2. 2. 2.] Zn, [2. 2. 0.] O, [...
#
#                                           ase_structure   idx  \
# 0     (Atom('La', [8e-06, 4.000008, 4.000008], index...   227
# 1     (Atom('Ba', [0.0, 0.0, 0.0], index=0), Atom('B...  2291
# 2     (Atom('Sr', [8e-06, 8e-06, 8e-06], index=0), A...  3303
# 3     (Atom('Ca', [8e-06, 4.000008, 4.000008], index...  2161
# 4     (Atom('La', [8e-06, 8e-06, 8e-06], index=0), A...  2545
# ...                                                 ...   ...
# 6271  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('T...  2654
# 6272  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('T...  2655
# 6273  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('V...  2656
# 6274  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('Y...  2657
# 6275  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('Z...  2658
#
#                                                   atoms
# 0     {'elements': ['La', 'Cr', 'O', 'O', 'O', 'La',...
# 1     {'elements': ['Ba', 'Ba', 'Ba', 'Ba', 'Ac', 'A...
# 2     {'elements': ['Sr', 'Hf', 'O', 'O', 'O', 'Pb',...
# 3     {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# 4     {'elements': ['La', 'Cr', 'O', 'O', 'O', 'La',...
# ...                                                 ...
# 6271  {'elements': ['Zr', 'Te', 'O', 'O', 'O', 'Zr',...
# 6272  {'elements': ['Zr', 'Tl', 'O', 'O', 'O', 'Zr',...
# 6273  {'elements': ['Zr', 'V', 'O', 'O', 'O', 'Zr', ...
# 6274  {'elements': ['Zr', 'Y', 'O', 'O', 'O', 'Zr', ...
# 6275  {'elements': ['Zr', 'Zn', 'O', 'O', 'O', 'Zr',...
#
# [6276 rows x 18 columns]
# building line graphs
# 100%|██████████| 6276/6276 [00:07<00:00, 850.26it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 1261/1261 [00:00<00:00, 8794.67it/s]
# data range 0.44672706030000003 0.0
# Converting to graphs!
# 100%|██████████| 1261/1261 [00:18<00:00, 67.04it/s]
# df               formula                       framework  \
# 0     Ba2Cr4Mn4O24Pr6  Ba0.250Pr0.750Cr0.500Mn0.500O3
# 1     Ba2Cr4Mn4O24Pr6  Ba0.250Pr0.750Cr0.500Mn0.500O3
# 2     Ba2Fe4Ni4O24Pr6  Ba0.250Pr0.750Fe0.500Ni0.500O3
# 3     Ba2Fe4Ni4O24Pr6  Ba0.250Pr0.750Fe0.500Ni0.500O3
# 4     Ba3Ca5Co1Ni7O24  Ba0.375Ca0.625Co0.125Ni0.875O3
# ...               ...                             ...
# 1256      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1257      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1258      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1259      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
# 1260      Cu4Mn4O24Y8               YCu0.500Mn0.500O3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Ba', 'Pr'], 'B': ['Cr', 'Mn'...                 40
# 1     {'sites': {'A': ['Ba', 'Pr'], 'B': ['Cr', 'Mn'...                 40
# 2     {'sites': {'A': ['Pr', 'Ba'], 'B': ['Fe', 'Ni'...                 40
# 3     {'sites': {'A': ['Pr', 'Ba'], 'B': ['Fe', 'Ni'...                 40
# 4     {'sites': {'A': ['Ba', 'Ca'], 'B': ['Co', 'Ni'...                 40
# ...                                                 ...                ...
# 1256  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1257  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1258  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1259  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
# 1260  {'sites': {'A': ['Y'], 'B': ['Cu', 'Mn'], 'X':...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           200879856
# 1              40           201883019
# 2              40           222996848
# 3              40           222996849
# 4              40           222996910
# ...           ...                 ...
# 1256           40           272062453
# 1257           40           272062454
# 1258           40           272062455
# 1259           40           272062457
# 1260           40           272062456
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     419905109
# 1     {'@module': 'pymatgen.core.structure', '@class...     423959303
# 2     {'@module': 'pymatgen.core.structure', '@class...     419905248
# 3     {'@module': 'pymatgen.core.structure', '@class...     420168914
# 4     {'@module': 'pymatgen.core.structure', '@class...     419905120
# ...                                                 ...           ...
# 1256  {'@module': 'pymatgen.core.structure', '@class...     421466164
# 1257  {'@module': 'pymatgen.core.structure', '@class...     421562098
# 1258  {'@module': 'pymatgen.core.structure', '@class...     421466146
# 1259  {'@module': 'pymatgen.core.structure', '@class...     421446133
# 1260  {'@module': 'pymatgen.core.structure', '@class...     421448171
#
#                                              opt_struct  es_job_id  ...  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  122894567  ...
# 1     {'@module': 'pymatgen.core.structure', '@class...  123103478  ...
# 2     {'@module': 'pymatgen.core.structure', '@class...  122894599  ...
# 3     {'@module': 'pymatgen.core.structure', '@class...  122914674  ...
# 4     {'@module': 'pymatgen.core.structure', '@class...  122894577  ...
# ...                                                 ...        ...  ...
# 1256  {'@module': 'pymatgen.core.structure', '@class...  122979645  ...
# 1257  {'@module': 'pymatgen.core.structure', '@class...  122988181  ...
# 1258  {'@module': 'pymatgen.core.structure', '@class...  122979642  ...
# 1259  {'@module': 'pymatgen.core.structure', '@class...  122979075  ...
# 1260  {'@module': 'pymatgen.core.structure', '@class...  122979218  ...
#
#       M3Gnet_relaxed_energy_per_atom  CHGNet_relaxed_energy  \
# 0                          -7.729604            -341.100922
# 1                          -7.743665            -341.377296
# 2                          -6.695003            -302.698708
# 3                          -6.711643            -303.274498
# 4                          -5.364596            -249.942665
# ...                              ...                    ...
# 1256                       -7.698078            -330.600357
# 1257                       -7.683108            -331.823959
# 1258                       -7.707710            -332.275696
# 1259                       -7.682349            -332.135582
# 1260                       -7.677264            -330.988693
#
#       CHGNet_energy_correction  CHGNet_relaxed_energy_per_atom_corrected  \
# 0                      -31.156                                 -7.748623
# 1                      -31.156                                 -7.755532
# 2                      -35.676                                 -6.675568
# 3                      -35.676                                 -6.689962
# 4                      -35.913                                 -5.350742
# ...                        ...                                       ...
# 1256                   -23.160                                 -7.686009
# 1257                   -23.160                                 -7.716599
# 1258                   -23.160                                 -7.727892
# 1259                   -23.160                                 -7.724390
# 1260                   -23.160                                 -7.695717
#
#       MACE_relaxed_energy  MACE_relaxed_energy_per_atom  \
# 0             -310.140472                     -7.753512
# 1             -310.617950                     -7.765449
# 2             -268.719086                     -6.717977
# 3             -269.109955                     -6.727749
# 4             -215.761551                     -5.394039
# ...                   ...                           ...
# 1256          -309.514526                     -7.737863
# 1257          -309.492981                     -7.737325
# 1258          -309.585693                     -7.739642
# 1259          -309.614899                     -7.740372
# 1260          -309.509247                     -7.737731
#
#                                               structure  \
# 0     [[8.e-06 8.e-06 8.e-06] Ba, [8.000000e-06 4.00...
# 1     [[8.e-06 8.e-06 8.e-06] Ba, [8.000000e-06 8.00...
# 2     [[8.e-06 8.e-06 8.e-06] Ba, [2.000008 2.000008...
# 3     [[8.e-06 8.e-06 8.e-06] Ba, [2.000008 2.000008...
# 4     [[0. 0. 0.] Ba, [2. 2. 2.] Co, [2. 2. 0.] O, [...
# ...                                                 ...
# 1256  [[6.000008 2.000008 2.000008] Y, [8.000000e-06...
# 1257  [[6.000008 2.000008 2.000008] Y, [8.000000e-06...
# 1258  [[6.000008 2.000008 2.000008] Y, [8.000000e-06...
# 1259  [[6.000008 6.000008 2.000008] Y, [8.000000e-06...
# 1260  [[6.000008 2.000008 6.000008] Y, [8.000000e-06...
#
#                                           ase_structure   idx  \
# 0     (Atom('Ba', [8e-06, 8e-06, 8.000000000000001e-...     0
# 1     (Atom('Ba', [8e-06, 8e-06, 8.000000000000001e-...     1
# 2     (Atom('Ba', [8e-06, 8e-06, 8e-06], index=0), A...     2
# 3     (Atom('Ba', [8e-06, 8e-06, 8e-06], index=0), A...     3
# 4     (Atom('Ba', [0.0, 0.0, 0.0], index=0), Atom('C...     4
# ...                                                 ...   ...
# 1256  (Atom('Y', [6.000007999999999, 2.000008, 2.000...  1256
# 1257  (Atom('Y', [6.000007999999999, 2.000008, 2.000...  1257
# 1258  (Atom('Y', [6.000007999999999, 2.000008, 2.000...  1258
# 1259  (Atom('Y', [6.000007999999999, 6.0000079999999...  1259
# 1260  (Atom('Y', [6.000007999999999, 2.000008, 6.000...  1260
#
#                                                   atoms
# 0     {'elements': ['Ba', 'Ba', 'Pr', 'Pr', 'Pr', 'P...
# 1     {'elements': ['Ba', 'Ba', 'Pr', 'Pr', 'Pr', 'P...
# 2     {'elements': ['Ba', 'Ni', 'O', 'O', 'O', 'Pr',...
# 3     {'elements': ['Ba', 'Ni', 'O', 'O', 'O', 'Ba',...
# 4     {'elements': ['Ba', 'Co', 'O', 'O', 'O', 'Ba',...
# ...                                                 ...
# 1256  {'elements': ['Y', 'Mn', 'O', 'O', 'O', 'Y', '...
# 1257  {'elements': ['Y', 'Mn', 'O', 'O', 'O', 'Y', '...
# 1258  {'elements': ['Y', 'Mn', 'O', 'O', 'O', 'Y', '...
# 1259  {'elements': ['Y', 'Mn', 'O', 'O', 'O', 'Y', '...
# 1260  {'elements': ['Y', 'Mn', 'O', 'O', 'O', 'Y', '...
#
# [1261 rows x 25 columns]
# building line graphs
# 100%|██████████| 1261/1261 [00:01<00:00, 963.05it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 6276/6276 [00:02<00:00, 2714.52it/s]
# 100%|██████████| 6276/6276 [00:02<00:00, 2808.41it/s]
# 100%|██████████| 6276/6276 [00:02<00:00, 2851.01it/s]
# Completed embedding extraction for test_set
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8770.53it/s]
# data range 1.5473600840000001 0.0
# Converting to graphs!
# 100%|██████████| 6276/6276 [01:31<00:00, 68.37it/s]
# df               formula                       framework  \
# 0     Cr1La4Ni7O24Pr4  La0.500Pr0.500Cr0.125Ni0.875O3
# 1     Ac4Ba4O24Ru3Tc5  Ac0.500Ba0.500Ru0.375Tc0.625O3
# 2     Hf3Mn5O24Pb7Sr1  Pb0.875Sr0.125Hf0.375Mn0.625O3
# 3        Ca4Fe8O24Sr4              Ca0.500Sr0.500FeO3
# 4     Cr1La3O24Rb5Ru7  La0.375Rb0.625Cr0.125Ru0.875O3
# ...               ...                             ...
# 6271         O3Te1Zr1                          ZrTeO3
# 6272         O3Tl1Zr1                          ZrTlO3
# 6273          O3V1Zr1                           ZrVO3
# 6274          O3Y1Zr1                           ZrYO3
# 6275         O3Zn1Zr1                          ZrZnO3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Pr', 'La'], 'B': ['Ni', 'Cr'...                 40
# 1     {'sites': {'A': ['Ac', 'Ba'], 'B': ['Ru', 'Tc'...                 40
# 2     {'sites': {'A': ['Sr', 'Pb'], 'B': ['Hf', 'Mn'...                 40
# 3     {'sites': {'A': ['Sr', 'Ca'], 'B': ['Fe'], 'X'...                 40
# 4     {'sites': {'A': ['La', 'Rb'], 'B': ['Cr', 'Ru'...                 40
# ...                                                 ...                ...
# 6271  {'sites': {'A': ['Zr'], 'B': ['Te'], 'X': ['O'...                 40
# 6272  {'sites': {'A': ['Zr'], 'B': ['Tl'], 'X': ['O'...                 40
# 6273  {'sites': {'A': ['Zr'], 'B': ['V'], 'X': ['O']...                 40
# 6274  {'sites': {'A': ['Zr'], 'B': ['Y'], 'X': ['O']...                 40
# 6275  {'sites': {'A': ['Zr'], 'B': ['Zn'], 'X': ['O'...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           222996458
# 1              40           149371528
# 2              40           205328812
# 3              40           222997894
# 4              40           205327484
# ...           ...                 ...
# 6271           40           137459436
# 6272           40           137458818
# 6273           40           137458560
# 6274           40           137460704
# 6275           40           137460691
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     427514528
# 1     {'@module': 'pymatgen.core.structure', '@class...     429562277
# 2     {'@module': 'pymatgen.core.structure', '@class...     458313128
# 3     {'@module': 'pymatgen.core.structure', '@class...     428493961
# 4     {'@module': 'pymatgen.core.structure', '@class...     255169844
# ...                                                 ...           ...
# 6271  {'@module': 'pymatgen.core.structure', '@class...     472477145
# 6272  {'@module': 'pymatgen.core.structure', '@class...     472811076
# 6273  {'@module': 'pymatgen.core.structure', '@class...     452734370
# 6274  {'@module': 'pymatgen.core.structure', '@class...     467990988
# 6275  {'@module': 'pymatgen.core.structure', '@class...     472539926
#
#                                              opt_struct  es_job_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  123322811
# 1     {'@module': 'pymatgen.core.structure', '@class...  123777852
# 2     {'@module': 'pymatgen.core.structure', '@class...  125437062
# 3     {'@module': 'pymatgen.core.structure', '@class...  123744086
# 4     {'@module': 'pymatgen.core.structure', '@class...   73683918
# ...                                                 ...        ...
# 6271  {'@module': 'pymatgen.core.structure', '@class...  127179422
# 6272  {'@module': 'pymatgen.core.structure', '@class...  127268711
# 6273  {'@module': 'pymatgen.core.structure', '@class...  125403163
# 6274  {'@module': 'pymatgen.core.structure', '@class...  126849119
# 6275  {'@module': 'pymatgen.core.structure', '@class...  127202068
#
#       dft_energy  dft_energy_per_atom  dft_e_hull  Op_band_center  \
# 0    -269.429516            -6.735738    0.102901       -1.912445
# 1    -305.132412            -7.628310    0.056276       -3.734871
# 2    -284.495242            -7.112381    0.123631       -1.555486
# 3    -253.347368            -6.333684    0.061250       -1.356781
# 4    -273.835152            -6.845879    0.101305       -3.132304
# ...          ...                  ...         ...             ...
# 6271 -295.360238            -7.384006    0.252080       -3.400961
# 6272 -288.728572            -7.218214    0.211370       -1.599369
# 6273 -349.386755            -8.734669    0.142448       -4.228963
# 6274 -363.619517            -9.090488    0.204514       -4.738996
# 6275 -291.492909            -7.287323    0.235271       -1.762010
#
#                                               structure  \
# 0     [[8.000000e-06 4.000008e+00 4.000008e+00] La, ...
# 1     [[0. 0. 0.] Ba, [0. 0. 4.] Ba, [0.0000000e+00 ...
# 2     [[8.e-06 8.e-06 8.e-06] Sr, [2.000008 2.000008...
# 3     [[8.000000e-06 4.000008e+00 4.000008e+00] Ca, ...
# 4     [[8.e-06 8.e-06 8.e-06] La, [2.000008 2.000008...
# ...                                                 ...
# 6271  [[0. 0. 0.] Zr, [2. 2. 2.] Te, [2. 2. 0.] O, [...
# 6272  [[0. 0. 0.] Zr, [2. 2. 2.] Tl, [2. 2. 0.] O, [...
# 6273  [[0. 0. 0.] Zr, [2. 2. 2.] V, [2. 2. 0.] O, [0...
# 6274  [[0. 0. 0.] Zr, [2. 2. 2.] Y, [2. 2. 0.] O, [0...
# 6275  [[0. 0. 0.] Zr, [2. 2. 2.] Zn, [2. 2. 0.] O, [...
#
#                                           ase_structure   idx  \
# 0     (Atom('La', [8e-06, 4.000008, 4.000008], index...   227
# 1     (Atom('Ba', [0.0, 0.0, 0.0], index=0), Atom('B...  2291
# 2     (Atom('Sr', [8e-06, 8e-06, 8e-06], index=0), A...  3303
# 3     (Atom('Ca', [8e-06, 4.000008, 4.000008], index...  2161
# 4     (Atom('La', [8e-06, 8e-06, 8e-06], index=0), A...  2545
# ...                                                 ...   ...
# 6271  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('T...  2654
# 6272  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('T...  2655
# 6273  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('V...  2656
# 6274  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('Y...  2657
# 6275  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('Z...  2658
#
#                                                   atoms
# 0     {'elements': ['La', 'Cr', 'O', 'O', 'O', 'La',...
# 1     {'elements': ['Ba', 'Ba', 'Ba', 'Ba', 'Ac', 'A...
# 2     {'elements': ['Sr', 'Hf', 'O', 'O', 'O', 'Pb',...
# 3     {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# 4     {'elements': ['La', 'Cr', 'O', 'O', 'O', 'La',...
# ...                                                 ...
# 6271  {'elements': ['Zr', 'Te', 'O', 'O', 'O', 'Zr',...
# 6272  {'elements': ['Zr', 'Tl', 'O', 'O', 'O', 'Zr',...
# 6273  {'elements': ['Zr', 'V', 'O', 'O', 'O', 'Zr', ...
# 6274  {'elements': ['Zr', 'Y', 'O', 'O', 'O', 'Zr', ...
# 6275  {'elements': ['Zr', 'Zn', 'O', 'O', 'O', 'Zr',...
#
# [6276 rows x 18 columns]
# building line graphs
# 100%|██████████| 6276/6276 [00:06<00:00, 954.74it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 600/600 [00:00<00:00, 8624.90it/s]
# data range 0.2306971018 0.0
# Converting to graphs!
# 100%|██████████| 600/600 [00:09<00:00, 65.19it/s]
# df           formula           framework  \
# 0    Ca8Fe4Mn4O24  CaFe0.500Mn0.500O3
# 1    Ca8Fe4Mn4O24  CaFe0.500Mn0.500O3
# 2    Ca8Fe4Mn4O24  CaFe0.500Mn0.500O3
# 3    Ca8Fe4Mn4O24  CaFe0.500Mn0.500O3
# 4    Ca8Fe4Mn4O24  CaFe0.500Mn0.500O3
# ..            ...                 ...
# 595  Mn4Ni4O24Tb8  TbMn0.500Ni0.500O3
# 596  Mn4Ni4O24Tb8  TbMn0.500Ni0.500O3
# 597  Mn4Ni4O24Tb8  TbMn0.500Ni0.500O3
# 598  Mn4Ni4O24Tb8  TbMn0.500Ni0.500O3
# 599  Mn4Ni4O24Tb8  TbMn0.500Ni0.500O3
#
#                                            composition  n_atoms_unrelaxed  \
# 0    {'sites': {'A': ['Ca'], 'B': ['Mn', 'Fe'], 'X'...                 40
# 1    {'sites': {'A': ['Ca'], 'B': ['Mn', 'Fe'], 'X'...                 40
# 2    {'sites': {'A': ['Ca'], 'B': ['Mn', 'Fe'], 'X'...                 40
# 3    {'sites': {'A': ['Ca'], 'B': ['Mn', 'Fe'], 'X'...                 40
# 4    {'sites': {'A': ['Ca'], 'B': ['Mn', 'Fe'], 'X'...                 40
# ..                                                 ...                ...
# 595  {'sites': {'A': ['Tb'], 'B': ['Ni', 'Mn'], 'X'...                 40
# 596  {'sites': {'A': ['Tb'], 'B': ['Ni', 'Mn'], 'X'...                 40
# 597  {'sites': {'A': ['Tb'], 'B': ['Ni', 'Mn'], 'X'...                 40
# 598  {'sites': {'A': ['Tb'], 'B': ['Ni', 'Mn'], 'X'...                 40
# 599  {'sites': {'A': ['Tb'], 'B': ['Ni', 'Mn'], 'X'...                 40
#
#      n_atoms_opt  unrelaxed_cryst_id  \
# 0             40           222998128
# 1             40           222998125
# 2             40           222998126
# 3             40           222998127
# 4             40           222998129
# ..           ...                 ...
# 595           40           272062436
# 596           40           272062439
# 597           40           272062435
# 598           40           272062438
# 599           40           272062434
#
#                                       unrelaxed_struct  opt_cryst_id  \
# 0    {'@module': 'pymatgen.core.structure', '@class...     423959398
# 1    {'@module': 'pymatgen.core.structure', '@class...     421466237
# 2    {'@module': 'pymatgen.core.structure', '@class...     421466235
# 3    {'@module': 'pymatgen.core.structure', '@class...     421466263
# 4    {'@module': 'pymatgen.core.structure', '@class...     421466289
# ..                                                 ...           ...
# 595  {'@module': 'pymatgen.core.structure', '@class...     421446419
# 596  {'@module': 'pymatgen.core.structure', '@class...     421459053
# 597  {'@module': 'pymatgen.core.structure', '@class...     421464614
# 598  {'@module': 'pymatgen.core.structure', '@class...     421446230
# 599  {'@module': 'pymatgen.core.structure', '@class...     421466265
#
#                                             opt_struct  es_job_id  ...  \
# 0    {'@module': 'pymatgen.core.structure', '@class...  123103556  ...
# 1    {'@module': 'pymatgen.core.structure', '@class...  122979400  ...
# 2    {'@module': 'pymatgen.core.structure', '@class...  122979657  ...
# 3    {'@module': 'pymatgen.core.structure', '@class...  122979417  ...
# 4    {'@module': 'pymatgen.core.structure', '@class...  122979438  ...
# ..                                                 ...        ...  ...
# 595  {'@module': 'pymatgen.core.structure', '@class...  122979607  ...
# 596  {'@module': 'pymatgen.core.structure', '@class...  122979241  ...
# 597  {'@module': 'pymatgen.core.structure', '@class...  122979281  ...
# 598  {'@module': 'pymatgen.core.structure', '@class...  122979130  ...
# 599  {'@module': 'pymatgen.core.structure', '@class...  122979419  ...
#
#      M3Gnet_relaxed_energy_per_atom  CHGNet_relaxed_energy  \
# 0                         -6.667781            -298.803921
# 1                         -6.661421            -298.802624
# 2                         -6.655347            -298.701477
# 3                         -6.616776            -298.694363
# 4                         -6.657716            -298.751240
# ..                              ...                    ...
# 595                       -7.248841            -327.067986
# 596                       -7.252887            -326.073685
# 597                       -7.290968            -325.861549
# 598                       -7.303135            -327.198486
# 599                       -7.288586            -326.700478
#
#      CHGNet_energy_correction  CHGNet_relaxed_energy_per_atom_corrected  \
# 0                     -32.184                                 -6.665498
# 1                     -32.184                                 -6.665466
# 2                     -32.184                                 -6.662937
# 3                     -32.184                                 -6.662759
# 4                     -32.184                                 -6.664181
# ..                        ...                                       ...
# 595                   -33.324                                 -7.343600
# 596                   -33.324                                 -7.318742
# 597                   -33.324                                 -7.313439
# 598                   -33.324                                 -7.346862
# 599                   -33.324                                 -7.334412
#
#      MACE_relaxed_energy  MACE_relaxed_energy_per_atom  \
# 0            -267.581879                     -6.689547
# 1            -267.282410                     -6.682060
# 2            -267.429810                     -6.685745
# 3            -267.430603                     -6.685765
# 4            -267.576508                     -6.689413
# ..                   ...                           ...
# 595          -294.585846                     -7.364646
# 596          -295.542816                     -7.388570
# 597          -294.574310                     -7.364358
# 598          -294.928925                     -7.373223
# 599          -294.324799                     -7.358120
#
#                                              structure  \
# 0    [[6.000008 2.000008 2.000008] Ca, [8.000000e-0...
# 1    [[0. 0. 0.] Ca, [2. 2. 2.] Fe, [2. 2. 0.] O, [...
# 2    [[6.000008 2.000008 2.000008] Ca, [8.000000e-0...
# 3    [[6.000008 2.000008 2.000008] Ca, [8.000000e-0...
# 4    [[6.000008 2.000008 6.000008] Ca, [8.000000e-0...
# ..                                                 ...
# 595  [[6.000008 2.000008 2.000008] Tb, [8.000000e-0...
# 596  [[6.000008 6.000008 2.000008] Tb, [8.000000e-0...
# 597  [[6.000008 2.000008 2.000008] Tb, [8.000000e-0...
# 598  [[6.000008 2.000008 6.000008] Tb, [8.000000e-0...
# 599  [[0. 0. 0.] Tb, [2. 2. 2.] Mn, [2. 2. 0.] O, [...
#
#                                          ase_structure  idx  \
# 0    (Atom('Ca', [6.000007999999999, 2.000008, 2.00...    0
# 1    (Atom('Ca', [0.0, 0.0, 0.0], index=0), Atom('F...    1
# 2    (Atom('Ca', [6.000007999999999, 2.000008, 2.00...    2
# 3    (Atom('Ca', [6.000007999999999, 2.000008, 2.00...    3
# 4    (Atom('Ca', [6.000007999999999, 2.000008, 6.00...    4
# ..                                                 ...  ...
# 595  (Atom('Tb', [6.000007999999999, 2.000008, 2.00...  595
# 596  (Atom('Tb', [6.000007999999999, 6.000007999999...  596
# 597  (Atom('Tb', [6.000007999999999, 2.000008, 2.00...  597
# 598  (Atom('Tb', [6.000007999999999, 2.000008, 6.00...  598
# 599  (Atom('Tb', [0.0, 0.0, 0.0], index=0), Atom('M...  599
#
#                                                  atoms
# 0    {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# 1    {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# 2    {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# 3    {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# 4    {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# ..                                                 ...
# 595  {'elements': ['Tb', 'Mn', 'O', 'O', 'O', 'Tb',...
# 596  {'elements': ['Tb', 'Mn', 'O', 'O', 'O', 'Tb',...
# 597  {'elements': ['Tb', 'Mn', 'O', 'O', 'O', 'Tb',...
# 598  {'elements': ['Tb', 'Mn', 'O', 'O', 'O', 'Tb',...
# 599  {'elements': ['Tb', 'Mn', 'O', 'O', 'O', 'Tb',...
#
# [600 rows x 25 columns]
# building line graphs
# 100%|██████████| 600/600 [00:00<00:00, 924.38it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 6276/6276 [00:02<00:00, 2639.86it/s]
# 100%|██████████| 6276/6276 [00:02<00:00, 2830.82it/s]
# 100%|██████████| 6276/6276 [00:02<00:00, 2835.87it/s]
# Completed embedding extraction for holdout_set_B_sites
# Loaded data
# Completed data processing
# 100%|██████████| 6276/6276 [00:00<00:00, 8993.87it/s]
# data range 1.5473600840000001 0.0
# Converting to graphs!
#  31%|███       | 1919/6276 [00:27<00:57, 75.97it/s]Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7da6de3d9540>>
# Traceback (most recent call last):
#   File "/data/users/kritarth/.conda/envs/Perovskite_ML_Environment/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# 100%|██████████| 6276/6276 [01:31<00:00, 68.29it/s]
# df               formula                       framework  \
# 0     Cr1La4Ni7O24Pr4  La0.500Pr0.500Cr0.125Ni0.875O3
# 1     Ac4Ba4O24Ru3Tc5  Ac0.500Ba0.500Ru0.375Tc0.625O3
# 2     Hf3Mn5O24Pb7Sr1  Pb0.875Sr0.125Hf0.375Mn0.625O3
# 3        Ca4Fe8O24Sr4              Ca0.500Sr0.500FeO3
# 4     Cr1La3O24Rb5Ru7  La0.375Rb0.625Cr0.125Ru0.875O3
# ...               ...                             ...
# 6271         O3Te1Zr1                          ZrTeO3
# 6272         O3Tl1Zr1                          ZrTlO3
# 6273          O3V1Zr1                           ZrVO3
# 6274          O3Y1Zr1                           ZrYO3
# 6275         O3Zn1Zr1                          ZrZnO3
#
#                                             composition  n_atoms_unrelaxed  \
# 0     {'sites': {'A': ['Pr', 'La'], 'B': ['Ni', 'Cr'...                 40
# 1     {'sites': {'A': ['Ac', 'Ba'], 'B': ['Ru', 'Tc'...                 40
# 2     {'sites': {'A': ['Sr', 'Pb'], 'B': ['Hf', 'Mn'...                 40
# 3     {'sites': {'A': ['Sr', 'Ca'], 'B': ['Fe'], 'X'...                 40
# 4     {'sites': {'A': ['La', 'Rb'], 'B': ['Cr', 'Ru'...                 40
# ...                                                 ...                ...
# 6271  {'sites': {'A': ['Zr'], 'B': ['Te'], 'X': ['O'...                 40
# 6272  {'sites': {'A': ['Zr'], 'B': ['Tl'], 'X': ['O'...                 40
# 6273  {'sites': {'A': ['Zr'], 'B': ['V'], 'X': ['O']...                 40
# 6274  {'sites': {'A': ['Zr'], 'B': ['Y'], 'X': ['O']...                 40
# 6275  {'sites': {'A': ['Zr'], 'B': ['Zn'], 'X': ['O'...                 40
#
#       n_atoms_opt  unrelaxed_cryst_id  \
# 0              40           222996458
# 1              40           149371528
# 2              40           205328812
# 3              40           222997894
# 4              40           205327484
# ...           ...                 ...
# 6271           40           137459436
# 6272           40           137458818
# 6273           40           137458560
# 6274           40           137460704
# 6275           40           137460691
#
#                                        unrelaxed_struct  opt_cryst_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...     427514528
# 1     {'@module': 'pymatgen.core.structure', '@class...     429562277
# 2     {'@module': 'pymatgen.core.structure', '@class...     458313128
# 3     {'@module': 'pymatgen.core.structure', '@class...     428493961
# 4     {'@module': 'pymatgen.core.structure', '@class...     255169844
# ...                                                 ...           ...
# 6271  {'@module': 'pymatgen.core.structure', '@class...     472477145
# 6272  {'@module': 'pymatgen.core.structure', '@class...     472811076
# 6273  {'@module': 'pymatgen.core.structure', '@class...     452734370
# 6274  {'@module': 'pymatgen.core.structure', '@class...     467990988
# 6275  {'@module': 'pymatgen.core.structure', '@class...     472539926
#
#                                              opt_struct  es_job_id  \
# 0     {'@module': 'pymatgen.core.structure', '@class...  123322811
# 1     {'@module': 'pymatgen.core.structure', '@class...  123777852
# 2     {'@module': 'pymatgen.core.structure', '@class...  125437062
# 3     {'@module': 'pymatgen.core.structure', '@class...  123744086
# 4     {'@module': 'pymatgen.core.structure', '@class...   73683918
# ...                                                 ...        ...
# 6271  {'@module': 'pymatgen.core.structure', '@class...  127179422
# 6272  {'@module': 'pymatgen.core.structure', '@class...  127268711
# 6273  {'@module': 'pymatgen.core.structure', '@class...  125403163
# 6274  {'@module': 'pymatgen.core.structure', '@class...  126849119
# 6275  {'@module': 'pymatgen.core.structure', '@class...  127202068
#
#       dft_energy  dft_energy_per_atom  dft_e_hull  Op_band_center  \
# 0    -269.429516            -6.735738    0.102901       -1.912445
# 1    -305.132412            -7.628310    0.056276       -3.734871
# 2    -284.495242            -7.112381    0.123631       -1.555486
# 3    -253.347368            -6.333684    0.061250       -1.356781
# 4    -273.835152            -6.845879    0.101305       -3.132304
# ...          ...                  ...         ...             ...
# 6271 -295.360238            -7.384006    0.252080       -3.400961
# 6272 -288.728572            -7.218214    0.211370       -1.599369
# 6273 -349.386755            -8.734669    0.142448       -4.228963
# 6274 -363.619517            -9.090488    0.204514       -4.738996
# 6275 -291.492909            -7.287323    0.235271       -1.762010
#
#                                               structure  \
# 0     [[8.000000e-06 4.000008e+00 4.000008e+00] La, ...
# 1     [[0. 0. 0.] Ba, [0. 0. 4.] Ba, [0.0000000e+00 ...
# 2     [[8.e-06 8.e-06 8.e-06] Sr, [2.000008 2.000008...
# 3     [[8.000000e-06 4.000008e+00 4.000008e+00] Ca, ...
# 4     [[8.e-06 8.e-06 8.e-06] La, [2.000008 2.000008...
# ...                                                 ...
# 6271  [[0. 0. 0.] Zr, [2. 2. 2.] Te, [2. 2. 0.] O, [...
# 6272  [[0. 0. 0.] Zr, [2. 2. 2.] Tl, [2. 2. 0.] O, [...
# 6273  [[0. 0. 0.] Zr, [2. 2. 2.] V, [2. 2. 0.] O, [0...
# 6274  [[0. 0. 0.] Zr, [2. 2. 2.] Y, [2. 2. 0.] O, [0...
# 6275  [[0. 0. 0.] Zr, [2. 2. 2.] Zn, [2. 2. 0.] O, [...
#
#                                           ase_structure   idx  \
# 0     (Atom('La', [8e-06, 4.000008, 4.000008], index...   227
# 1     (Atom('Ba', [0.0, 0.0, 0.0], index=0), Atom('B...  2291
# 2     (Atom('Sr', [8e-06, 8e-06, 8e-06], index=0), A...  3303
# 3     (Atom('Ca', [8e-06, 4.000008, 4.000008], index...  2161
# 4     (Atom('La', [8e-06, 8e-06, 8e-06], index=0), A...  2545
# ...                                                 ...   ...
# 6271  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('T...  2654
# 6272  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('T...  2655
# 6273  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('V...  2656
# 6274  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('Y...  2657
# 6275  (Atom('Zr', [0.0, 0.0, 0.0], index=0), Atom('Z...  2658
#
#                                                   atoms
# 0     {'elements': ['La', 'Cr', 'O', 'O', 'O', 'La',...
# 1     {'elements': ['Ba', 'Ba', 'Ba', 'Ba', 'Ac', 'A...
# 2     {'elements': ['Sr', 'Hf', 'O', 'O', 'O', 'Pb',...
# 3     {'elements': ['Ca', 'Fe', 'O', 'O', 'O', 'Ca',...
# 4     {'elements': ['La', 'Cr', 'O', 'O', 'O', 'La',...
# ...                                                 ...
# 6271  {'elements': ['Zr', 'Te', 'O', 'O', 'O', 'Zr',...
# 6272  {'elements': ['Zr', 'Tl', 'O', 'O', 'O', 'Zr',...
# 6273  {'elements': ['Zr', 'V', 'O', 'O', 'O', 'Zr', ...
# 6274  {'elements': ['Zr', 'Y', 'O', 'O', 'O', 'Zr', ...
# 6275  {'elements': ['Zr', 'Zn', 'O', 'O', 'O', 'Zr',...
#
# [6276 rows x 18 columns]
# building line graphs
# 100%|██████████| 6276/6276 [00:07<00:00, 800.85it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 863/863 [00:00<00:00, 8411.98it/s]
# data range 0.3612953374 0.0291272915
# Converting to graphs!
# 100%|██████████| 863/863 [00:12<00:00, 68.70it/s]
# df              formula                       framework  \
# 0    Bi2Cu4La6Mo4O24  Bi0.250La0.750Cu0.500Mo0.500O3
# 1    Bi2Cu4La6Mo4O24  Bi0.250La0.750Cu0.500Mo0.500O3
# 2    Bi2Cu4La6Mo4O24  Bi0.250La0.750Cu0.500Mo0.500O3
# 3    Bi2Cu4La6Mo4O24  Bi0.250La0.750Cu0.500Mo0.500O3
# 4    Bi2Cu4La6Mo4O24  Bi0.250La0.750Cu0.500Mo0.500O3
# ..               ...                             ...
# 858   Mg7Ni4O24Pr1V4   Mg0.875Pr0.125Ni0.500V0.500O3
# 859   Mg7Ni4O24Pr1V4   Mg0.875Pr0.125Ni0.500V0.500O3
# 860   Mg7Ni4O24Pr1V4   Mg0.875Pr0.125Ni0.500V0.500O3
# 861   Mg7Ni4O24Pr1V4   Mg0.875Pr0.125Ni0.500V0.500O3
# 862   Mg7Ni4O24Pr1V4   Mg0.875Pr0.125Ni0.500V0.500O3
#
#                                            composition  n_atoms_unrelaxed  \
# 0    {'sites': {'A': ['Bi', 'La'], 'B': ['Cu', 'Mo'...                 40
# 1    {'sites': {'A': ['Bi', 'La'], 'B': ['Cu', 'Mo'...                 40
# 2    {'sites': {'A': ['Bi', 'La'], 'B': ['Cu', 'Mo'...                 40
# 3    {'sites': {'A': ['Bi', 'La'], 'B': ['Cu', 'Mo'...                 40
# 4    {'sites': {'A': ['Bi', 'La'], 'B': ['Cu', 'Mo'...                 40
# ..                                                 ...                ...
# 858  {'sites': {'A': ['Mg', 'Pr'], 'B': ['Ni', 'V']...                 40
# 859  {'sites': {'A': ['Mg', 'Pr'], 'B': ['Ni', 'V']...                 40
# 860  {'sites': {'A': ['Mg', 'Pr'], 'B': ['Ni', 'V']...                 40
# 861  {'sites': {'A': ['Mg', 'Pr'], 'B': ['Ni', 'V']...                 40
# 862  {'sites': {'A': ['Mg', 'Pr'], 'B': ['Ni', 'V']...                 40
#
#      n_atoms_opt  unrelaxed_cryst_id  \
# 0             40           183674840
# 1             40           183674829
# 2             40           183674850
# 3             40           183674832
# 4             40           183674834
# ..           ...                 ...
# 858           40           183674255
# 859           40           183674250
# 860           40           183674253
# 861           40           183674254
# 862           40           183674251
#
#                                       unrelaxed_struct  opt_cryst_id  \
# 0    {'@module': 'pymatgen.core.structure', '@class...     421255705
# 1    {'@module': 'pymatgen.core.structure', '@class...     421255754
# 2    {'@module': 'pymatgen.core.structure', '@class...     423959399
# 3    {'@module': 'pymatgen.core.structure', '@class...     421255719
# 4    {'@module': 'pymatgen.core.structure', '@class...     423959434
# ..                                                 ...           ...
# 858  {'@module': 'pymatgen.core.structure', '@class...     436520773
# 859  {'@module': 'pymatgen.core.structure', '@class...     438904289
# 860  {'@module': 'pymatgen.core.structure', '@class...     439756697
# 861  {'@module': 'pymatgen.core.structure', '@class...     436520728
# 862  {'@module': 'pymatgen.core.structure', '@class...     440177160
#
#                                             opt_struct  es_job_id  ...  \
# 0    {'@module': 'pymatgen.core.structure', '@class...  122946754  ...
# 1    {'@module': 'pymatgen.core.structure', '@class...  122946790  ...
# 2    {'@module': 'pymatgen.core.structure', '@class...  123103557  ...
# 3    {'@module': 'pymatgen.core.structure', '@class...  122946765  ...
# 4    {'@module': 'pymatgen.core.structure', '@class...  123103586  ...
# ..                                                 ...        ...  ...
# 858  {'@module': 'pymatgen.core.structure', '@class...  124467329  ...
# 859  {'@module': 'pymatgen.core.structure', '@class...  124881872  ...
# 860  {'@module': 'pymatgen.core.structure', '@class...  124917879  ...
# 861  {'@module': 'pymatgen.core.structure', '@class...  124467292  ...
# 862  {'@module': 'pymatgen.core.structure', '@class...  124933261  ...
#
#      M3Gnet_relaxed_energy_per_atom  CHGNet_relaxed_energy  \
# 0                         -7.045885            -312.896080
# 1                         -7.060345            -312.516422
# 2                         -7.048989            -312.931499
# 3                         -7.044801            -311.946468
# 4                         -7.035557            -312.530994
# ..                              ...                    ...
# 858                       -6.272154            -285.657139
# 859                       -6.261201            -285.865688
# 860                       -6.240560            -285.586529
# 861                       -6.242931            -285.530357
# 862                       -6.271035            -285.110035
#
#      CHGNet_energy_correction  CHGNet_relaxed_energy_per_atom_corrected  \
# 0                     -29.296                                 -7.090002
# 1                     -29.296                                 -7.080511
# 2                     -29.296                                 -7.090887
# 3                     -29.296                                 -7.066262
# 4                     -29.296                                 -7.080875
# ..                        ...                                       ...
# 858                   -33.452                                 -6.305128
# 859                   -33.452                                 -6.310342
# 860                   -33.452                                 -6.303363
# 861                   -33.452                                 -6.301959
# 862                   -33.452                                 -6.291451
#
#      MACE_relaxed_energy  MACE_relaxed_energy_per_atom  \
# 0            -284.542480                     -7.113562
# 1            -284.684509                     -7.117113
# 2            -284.667725                     -7.116693
# 3            -284.592804                     -7.114820
# 4            -284.948944                     -7.123724
# ..                   ...                           ...
# 858          -254.207520                     -6.355188
# 859          -252.813263                     -6.320332
# 860          -252.626099                     -6.315652
# 861          -253.020416                     -6.325510
# 862          -253.432373                     -6.335809
#
#                                              structure  \
# 0    [[8.000000e-06 8.000000e-06 4.000008e+00] La, ...
# 1    [[8.000000e-06 4.000008e+00 8.000000e-06] La, ...
# 2    [[8.000000e-06 8.000000e-06 4.000008e+00] La, ...
# 3    [[8.000000e-06 4.000008e+00 8.000000e-06] La, ...
# 4    [[8.000000e-06 4.000008e+00 8.000000e-06] La, ...
# ..                                                 ...
# 858  [[8.e-06 8.e-06 8.e-06] Pr, [8.000000e-06 8.00...
# 859  [[0. 0. 0.] Pr, [0. 0. 4.] Mg, [0.0000000e+00 ...
# 860  [[8.e-06 8.e-06 8.e-06] Pr, [8.000000e-06 8.00...
# 861  [[8.e-06 8.e-06 8.e-06] Pr, [8.000000e-06 8.00...
# 862  [[8.e-06 8.e-06 8.e-06] Pr, [8.000000e-06 8.00...
#
#                                          ase_structure  idx  \
# 0    (Atom('La', [8e-06, 8e-06, 4.000008], index=0)...    0
# 1    (Atom('La', [8e-06, 4.000008, 8.00000000024493...    1
# 2    (Atom('La', [8e-06, 8e-06, 4.000008], index=0)...    2
# 3    (Atom('La', [8e-06, 4.000008, 8.00000000024493...    3
# 4    (Atom('La', [8e-06, 4.000008, 8.00000000024493...    4
# ..                                                 ...  ...
# 858  (Atom('Pr', [8e-06, 8e-06, 8.000000000000001e-...  858
# 859  (Atom('Pr', [0.0, 0.0, 0.0], index=0), Atom('M...  859
# 860  (Atom('Pr', [8e-06, 8e-06, 8.000000000000001e-...  860
# 861  (Atom('Pr', [8e-06, 8e-06, 8.000000000000001e-...  861
# 862  (Atom('Pr', [8e-06, 8e-06, 8.000000000000001e-...  862
#
#                                                  atoms
# 0    {'elements': ['La', 'La', 'La', 'La', 'La', 'L...
# 1    {'elements': ['La', 'La', 'La', 'La', 'La', 'L...
# 2    {'elements': ['La', 'La', 'La', 'La', 'La', 'L...
# 3    {'elements': ['La', 'La', 'La', 'La', 'La', 'L...
# 4    {'elements': ['La', 'La', 'La', 'La', 'La', 'L...
# ..                                                 ...
# 858  {'elements': ['Pr', 'Mg', 'Mg', 'Mg', 'Mg', 'M...
# 859  {'elements': ['Pr', 'Mg', 'Mg', 'Mg', 'Mg', 'M...
# 860  {'elements': ['Pr', 'Mg', 'Mg', 'Mg', 'Mg', 'M...
# 861  {'elements': ['Pr', 'Mg', 'Mg', 'Mg', 'Mg', 'M...
# 862  {'elements': ['Pr', 'Mg', 'Mg', 'Mg', 'Mg', 'M...
#
# [863 rows x 25 columns]
# building line graphs
# 100%|██████████| 863/863 [00:00<00:00, 1298.63it/s]
# Using single worker for ALIGNN dataloader to avoid CUDA multiprocessing issues
# 100%|██████████| 6276/6276 [00:02<00:00, 2698.59it/s]
# 100%|██████████| 6276/6276 [00:02<00:00, 2856.39it/s]
# 100%|██████████| 6276/6276 [00:02<00:00, 2816.26it/s]
# Completed embedding extraction for holdout_set_series
