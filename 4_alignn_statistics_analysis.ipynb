# %% [markdown]
# # ALIGNN Training Statistics Analysis
#
# **This notebook provides comprehensive statistical analysis for ALIGNN training results on both relaxed and unrelaxed perovskite structures.**
#
# Analysis includes:
# - Performance comparison between relaxed and unrelaxed structures
# - Hyperparameter optimization results
# - Model performance metrics (MAE, R², validation loss)
# - Statistical significance testing
# - Visualization of training convergence and results
